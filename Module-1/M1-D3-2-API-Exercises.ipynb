# %% [markdown]
# ### Working with APIs##
# #### CAS Applied Data Science 2024 ####
#
# #Exercises#

# %% [markdown]
# ---
#
#
# <font color='violet'>
# Hints are written in white, so you do not see them immediately. If you highlight them (or double-click on them), they will appear!
# <font color='white'> I am a hint! :-)
#
#
# ---

# %% [markdown]
# ## 1. Basic exercises

# %% [markdown]
# Note: In these exercises, you will have to work with dictionaries, list comprehensions and loops quite often. If you don't remember/understand them very well, you should first go through the respective concepts once more!

# %% [markdown]
# ### Exercise 1.1

# %% [markdown]
# Import the ``requests`` and the ``BeautifulSoup`` library.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Use the Wikipedia API to retrieve the Wikipedia page on tigers (Tiger).

# %%
ENDPOINT = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "parse",
    "page": "Tiger",
    "format": "json",
}

r = requests.get(url=ENDPOINT, params=PARAMS)

# %% [markdown]
# Parse the JSON response object (so that it is converted to a Python dictionary).

# %%
data = r.json()["parse"]

# %% [markdown]
# What is the URL you retrieved the data from? Type it into your browser and inspect the structure of the data.

# %%
https://en.wikipedia.org/w/api.php?page=Tiger&format=json&action=parse

# %% [markdown]
# Now inspect the keys of your dictionary (and those of the dictionary within the "parse" key)

# %%
data.keys()
# Out:
# dict_keys(['title', 'pageid', 'revid', 'text', 'langlinks', 'categories', 'links', 'templates', 'images', 'externallinks', 'sections', 'showtoc', 'parsewarnings', 'displaytitle', 'iwlinks', 'properties'])

# %% [markdown]
# Now try to retrieve the following:
#
# 1. The title of the page
# 2. All external links
# 3. All section headings (*extra task: all main section headings, i.e. headings on level 2)
# 4. The number of images in the article
# 5. All URLs to Wikipedia articles on tigers in other languages

# %%
# 1. The title of the page
data["title"]
# Out:
# 'Tiger'

# %%
# 2. All external links
[ link["url"] for link in data["iwlinks"]]
# Out:
# ['https://kk.wikipedia.org/wiki/%D0%86%D0%BB%D0%B5-%D0%91%D0%B0%D0%BB%D2%9B%D0%B0%D1%88_(%D1%80%D0%B5%D0%B7%D0%B5%D1%80%D0%B2%D0%B0%D1%82)',
#  'https://commons.wikimedia.org/wiki/Panthera_tigris',
#  'https://commons.wikimedia.org/wiki/Category:Panthera_tigris',
#  'https://species.wikimedia.org/wiki/Panthera_tigris',
#  'https://en.wikiquote.org/wiki/Tigers',
#  'https://en.wikivoyage.org/wiki/Tigers',
#  'https://www.wikidata.org/wiki/Q19939',
#  'https://www.wikidata.org/wiki/Q41083521',
#  'https://de.wikipedia.org/wiki/Tierstimmenarchiv']

# %%
# 3. All section headings
data["sections"]
[section["anchor"] for section in data["sections"]]
# Out:
# ['Etymology',
#  'Taxonomy',
#  'Subspecies',
#  'Evolution',
#  'Hybrids',
#  'Characteristics',
#  'Coat',
#  'Colour_variations',
#  'Distribution_and_habitat',
#  'Population_density',
#  'Behaviour_and_ecology',
#  'Social_spacing',
#  'Communication',
#  'Hunting_and_diet',
#  'Competitors',
#  'Reproduction_and_life_cycle',
#  'Health_and_diseases',
#  'Threats',
#  'Conservation',
#  'Relationship_with_humans',
#  'Hunting',
#  'Attacks',
#  'Captivity',
#  'Cultural_significance',
#  'See_also',
#  'References',
#  'Bibliography',
#  'External_links']

# %%
# 3. Extra task: all top level section headings (level 2)
data["sections"]
[section["anchor"]  for section in data["sections"] if section["toclevel"] == 2]
# Out:
# ['Subspecies',
#  'Evolution',
#  'Hybrids',
#  'Coat',
#  'Population_density',
#  'Social_spacing',
#  'Communication',
#  'Hunting_and_diet',
#  'Competitors',
#  'Reproduction_and_life_cycle',
#  'Health_and_diseases',
#  'Hunting',
#  'Attacks',
#  'Captivity',
#  'Cultural_significance',
#  'Bibliography']

# %%
# 4. The number of images in the article
data.keys()
data["images"]
length = len(data["images"])
print(f"Number of images: {length}")
# Out:
# Number of images: 63

# %%
# 5. All URLs to Wikipedia articles on tigers in other languages
print(data.keys())
data["langlinks"]
[{"lang": link["lang"], "url": link["url"]} for link in data["langlinks"]]
# Out:
# dict_keys(['title', 'pageid', 'revid', 'text', 'langlinks', 'categories', 'links', 'templates', 'images', 'externallinks', 'sections', 'showtoc', 'parsewarnings', 'displaytitle', 'iwlinks', 'properties'])
# [{'lang': 'ace', 'url': 'https://ace.wikipedia.org/wiki/Rimu%C3%ABng'},
#  {'lang': 'kbd',
#   'url': 'https://kbd.wikipedia.org/wiki/%D0%A5%D1%8C%D1%8D%D1%89%D0%BE%D0%BC%D1%8B%D1%89'},
#  {'lang': 'ady',
#   'url': 'https://ady.wikipedia.org/wiki/%D0%9A%D1%8A%D1%8D%D0%BF%D0%BB%D1%8A%D0%B0%D0%BD'},
#  {'lang': 'af', 'url': 'https://af.wikipedia.org/wiki/Tier'},
#  {'lang': 'als', 'url': 'https://als.wikipedia.org/wiki/Tiger'},
#  {'lang': 'am',
#   'url': 'https://am.wikipedia.org/wiki/%E1%8A%90%E1%89%A5%E1%88%AD'},
#  {'lang': 'anp',
#   'url': 'https://anp.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98'},
#  {'lang': 'ang', 'url': 'https://ang.wikipedia.org/wiki/Tiger'},
#  {'lang': 'ar', 'url': 'https://ar.wikipedia.org/wiki/%D8%A8%D8%A8%D8%B1'},
#  {'lang': 'an', 'url': 'https://an.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'roa-rup', 'url': 'https://roa-rup.wikipedia.org/wiki/Tigru'},
#  {'lang': 'ast', 'url': 'https://ast.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'gn', 'url': 'https://gn.wikipedia.org/wiki/Jaguareterusu'},
#  {'lang': 'az', 'url': 'https://az.wikipedia.org/wiki/P%C9%99l%C9%99ng'},
#  {'lang': 'azb',
#   'url': 'https://azb.wikipedia.org/wiki/%D9%82%D8%A7%D9%BE%D9%84%D8%A7%D9%86'},
#  {'lang': 'ban', 'url': 'https://ban.wikipedia.org/wiki/Macan'},
#  {'lang': 'bn',
#   'url': 'https://bn.wikipedia.org/wiki/%E0%A6%AC%E0%A6%BE%E0%A6%98'},
#  {'lang': 'zh-min-nan',
#   'url': 'https://zh-min-nan.wikipedia.org/wiki/H%C3%B3%CD%98'},
#  {'lang': 'ba',
#   'url': 'https://ba.wikipedia.org/wiki/%D0%AE%D0%BB%D0%B1%D0%B0%D1%80%D1%8B%D2%AB'},
#  {'lang': 'be',
#   'url': 'https://be.wikipedia.org/wiki/%D0%A2%D1%8B%D0%B3%D1%80'},
#  {'lang': 'be-x-old',
#   'url': 'https://be-tarask.wikipedia.org/wiki/%D0%A2%D1%8B%D0%B3%D1%80'},
#  {'lang': 'bh',
#   'url': 'https://bh.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98'},
#  {'lang': 'bcl', 'url': 'https://bcl.wikipedia.org/wiki/Tigre'},
#  {'lang': 'bg',
#   'url': 'https://bg.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%8A%D1%80'},
#  {'lang': 'bo',
#   'url': 'https://bo.wikipedia.org/wiki/%E0%BD%A6%E0%BE%9F%E0%BD%82'},
#  {'lang': 'bs', 'url': 'https://bs.wikipedia.org/wiki/Tigar'},
#  {'lang': 'br', 'url': 'https://br.wikipedia.org/wiki/Tigr'},
#  {'lang': 'bxr', 'url': 'https://bxr.wikipedia.org/wiki/%D0%91%D0%B0%D1%80'},
#  {'lang': 'ca', 'url': 'https://ca.wikipedia.org/wiki/Tigre'},
#  {'lang': 'cv',
#   'url': 'https://cv.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80'},
#  {'lang': 'ceb', 'url': 'https://ceb.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'cs', 'url': 'https://cs.wikipedia.org/wiki/Tygr'},
#  {'lang': 'co', 'url': 'https://co.wikipedia.org/wiki/Tigru'},
#  {'lang': 'cy', 'url': 'https://cy.wikipedia.org/wiki/Teigr'},
#  {'lang': 'da', 'url': 'https://da.wikipedia.org/wiki/Tiger'},
#  {'lang': 'de', 'url': 'https://de.wikipedia.org/wiki/Tiger'},
#  {'lang': 'nv',
#   'url': 'https://nv.wikipedia.org/wiki/N%C3%A1shd%C3%B3%C3%ADtsoh_nood%C7%AB%CC%81z%C3%ADg%C3%AD%C3%AD'},
#  {'lang': 'dty',
#   'url': 'https://dty.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%97'},
#  {'lang': 'dz',
#   'url': 'https://dz.wikipedia.org/wiki/%E0%BD%A6%E0%BE%9F%E0%BD%82'},
#  {'lang': 'et', 'url': 'https://et.wikipedia.org/wiki/Tiiger'},
#  {'lang': 'el',
#   'url': 'https://el.wikipedia.org/wiki/%CE%A4%CE%AF%CE%B3%CF%81%CE%B7'},
#  {'lang': 'es', 'url': 'https://es.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'eo', 'url': 'https://eo.wikipedia.org/wiki/Tigro'},
#  {'lang': 'eu', 'url': 'https://eu.wikipedia.org/wiki/Tigre'},
#  {'lang': 'fa', 'url': 'https://fa.wikipedia.org/wiki/%D8%A8%D8%A8%D8%B1'},
#  {'lang': 'fo', 'url': 'https://fo.wikipedia.org/wiki/Tikari'},
#  {'lang': 'fr', 'url': 'https://fr.wikipedia.org/wiki/Tigre'},
#  {'lang': 'ga', 'url': 'https://ga.wikipedia.org/wiki/T%C3%ADogar'},
#  {'lang': 'gag', 'url': 'https://gag.wikipedia.org/wiki/Kaplan'},
#  {'lang': 'gd', 'url': 'https://gd.wikipedia.org/wiki/T%C3%ACgear'},
#  {'lang': 'gl', 'url': 'https://gl.wikipedia.org/wiki/Tigre'},
#  {'lang': 'inh',
#   'url': 'https://inh.wikipedia.org/wiki/%D0%A6%D3%80%D0%BE%D0%BA%D1%8A'},
#  {'lang': 'gan', 'url': 'https://gan.wikipedia.org/wiki/%E8%80%81%E8%99%8E'},
#  {'lang': 'glk',
#   'url': 'https://glk.wikipedia.org/wiki/%D8%AF%DB%8A%D8%B1%DA%AF'},
#  {'lang': 'gu',
#   'url': 'https://gu.wikipedia.org/wiki/%E0%AA%B5%E0%AA%BE%E0%AA%98'},
#  {'lang': 'got',
#   'url': 'https://got.wikipedia.org/wiki/%F0%90%8D%84%F0%90%8C%B9%F0%90%8C%B2%F0%90%8D%82%F0%90%8D%83'},
#  {'lang': 'gom', 'url': 'https://gom.wikipedia.org/wiki/Vag'},
#  {'lang': 'hak', 'url': 'https://hak.wikipedia.org/wiki/Lo-f%C3%BA'},
#  {'lang': 'ko',
#   'url': 'https://ko.wikipedia.org/wiki/%ED%98%B8%EB%9E%91%EC%9D%B4'},
#  {'lang': 'hy',
#   'url': 'https://hy.wikipedia.org/wiki/%D5%8E%D5%A1%D5%A3%D6%80'},
#  {'lang': 'hi',
#   'url': 'https://hi.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98'},
#  {'lang': 'hsb', 'url': 'https://hsb.wikipedia.org/wiki/Tiger'},
#  {'lang': 'hr', 'url': 'https://hr.wikipedia.org/wiki/Tigar'},
#  {'lang': 'io', 'url': 'https://io.wikipedia.org/wiki/Tigro'},
#  {'lang': 'ilo', 'url': 'https://ilo.wikipedia.org/wiki/Tigre'},
#  {'lang': 'id', 'url': 'https://id.wikipedia.org/wiki/Harimau'},
#  {'lang': 'ia', 'url': 'https://ia.wikipedia.org/wiki/Tigre'},
#  {'lang': 'os',
#   'url': 'https://os.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80'},
#  {'lang': 'zu', 'url': 'https://zu.wikipedia.org/wiki/Ithayiga'},
#  {'lang': 'is', 'url': 'https://is.wikipedia.org/wiki/T%C3%ADgrisd%C3%BDr'},
#  {'lang': 'it', 'url': 'https://it.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'he',
#   'url': 'https://he.wikipedia.org/wiki/%D7%98%D7%99%D7%92%D7%A8%D7%99%D7%A1'},
#  {'lang': 'jv', 'url': 'https://jv.wikipedia.org/wiki/Macan'},
#  {'lang': 'kn',
#   'url': 'https://kn.wikipedia.org/wiki/%E0%B2%B9%E0%B3%81%E0%B2%B2%E0%B2%BF'},
#  {'lang': 'ka',
#   'url': 'https://ka.wikipedia.org/wiki/%E1%83%95%E1%83%94%E1%83%A4%E1%83%AE%E1%83%95%E1%83%98'},
#  {'lang': 'ks', 'url': 'https://ks.wikipedia.org/wiki/%D8%B4%DB%8C%D8%B1'},
#  {'lang': 'csb', 'url': 'https://csb.wikipedia.org/wiki/Azjacczi_tigris'},
#  {'lang': 'kk',
#   'url': 'https://kk.wikipedia.org/wiki/%D0%96%D0%BE%D0%BB%D0%B1%D0%B0%D1%80%D1%8B%D1%81'},
#  {'lang': 'kw', 'url': 'https://kw.wikipedia.org/wiki/Tiger'},
#  {'lang': 'sw', 'url': 'https://sw.wikipedia.org/wiki/Chui_milia'},
#  {'lang': 'avk',
#   'url': 'https://avk.wikipedia.org/wiki/Jaktol_(Panthera_tigris)'},
#  {'lang': 'ht', 'url': 'https://ht.wikipedia.org/wiki/Tig'},
#  {'lang': 'ku',
#   'url': 'https://ku.wikipedia.org/wiki/Piling_(Panthera_tigris)'},
#  {'lang': 'ky',
#   'url': 'https://ky.wikipedia.org/wiki/%D0%96%D0%BE%D0%BB%D0%B1%D0%BE%D1%80%D1%81'},
#  {'lang': 'lld', 'url': 'https://lld.wikipedia.org/wiki/Tigra'},
#  {'lang': 'lbe',
#   'url': 'https://lbe.wikipedia.org/wiki/%D0%9A%D1%8A%D0%B0%D0%BF%D0%BB%D0%B0%D0%BD'},
#  {'lang': 'ltg', 'url': 'https://ltg.wikipedia.org/wiki/Tygrys'},
#  {'lang': 'la', 'url': 'https://la.wikipedia.org/wiki/Tigris'},
#  {'lang': 'lv', 'url': 'https://lv.wikipedia.org/wiki/T%C4%AB%C4%A3eris'},
#  {'lang': 'lb', 'url': 'https://lb.wikipedia.org/wiki/Tiger'},
#  {'lang': 'lez',
#   'url': 'https://lez.wikipedia.org/wiki/%D0%9F%D0%B5%D0%BB%D0%B5%D0%BD%D0%B3'},
#  {'lang': 'lt', 'url': 'https://lt.wikipedia.org/wiki/Tigras'},
#  {'lang': 'nia', 'url': 'https://nia.wikipedia.org/wiki/Harimo'},
#  {'lang': 'li', 'url': 'https://li.wikipedia.org/wiki/Tieger'},
#  {'lang': 'ln',
#   'url': 'https://ln.wikipedia.org/wiki/Nk%C9%94i_et%C3%A1n%C3%A9'},
#  {'lang': 'lfn', 'url': 'https://lfn.wikipedia.org/wiki/Tigre'},
#  {'lang': 'jbo', 'url': 'https://jbo.wikipedia.org/wiki/tirxu'},
#  {'lang': 'lmo', 'url': 'https://lmo.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'hu', 'url': 'https://hu.wikipedia.org/wiki/Tigris_(%C3%A1llat)'},
#  {'lang': 'mai',
#   'url': 'https://mai.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98'},
#  {'lang': 'mk',
#   'url': 'https://mk.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D0%B0%D1%80'},
#  {'lang': 'mg', 'url': 'https://mg.wikipedia.org/wiki/Tigra'},
#  {'lang': 'ml',
#   'url': 'https://ml.wikipedia.org/wiki/%E0%B4%95%E0%B4%9F%E0%B5%81%E0%B4%B5'},
#  {'lang': 'mi', 'url': 'https://mi.wikipedia.org/wiki/Taika'},
#  {'lang': 'mr',
#   'url': 'https://mr.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BE%E0%A4%98'},
#  {'lang': 'xmf',
#   'url': 'https://xmf.wikipedia.org/wiki/%E1%83%B8%E1%83%98%E1%83%9A%E1%83%9D'},
#  {'lang': 'arz', 'url': 'https://arz.wikipedia.org/wiki/%D9%86%D9%85%D8%B1'},
#  {'lang': 'mzn',
#   'url': 'https://mzn.wikipedia.org/wiki/%D8%AF%D9%88%D8%B1%DA%AF'},
#  {'lang': 'ms', 'url': 'https://ms.wikipedia.org/wiki/Harimau'},
#  {'lang': 'mni',
#   'url': 'https://mni.wikipedia.org/wiki/%EA%AF%80%EA%AF%A9_(%EA%AF%81%EA%AF%A5)'},
#  {'lang': 'min', 'url': 'https://min.wikipedia.org/wiki/Harimau'},
#  {'lang': 'cdo', 'url': 'https://cdo.wikipedia.org/wiki/L%C3%A2u-h%C5%AB'},
#  {'lang': 'mdf',
#   'url': 'https://mdf.wikipedia.org/wiki/%D0%91%D0%B0%D0%B1%D1%80%D0%B8'},
#  {'lang': 'mn', 'url': 'https://mn.wikipedia.org/wiki/%D0%91%D0%B0%D1%80'},
#  {'lang': 'my',
#   'url': 'https://my.wikipedia.org/wiki/%E1%80%80%E1%80%BB%E1%80%AC%E1%80%B8'},
#  {'lang': 'nl', 'url': 'https://nl.wikipedia.org/wiki/Tijger'},
#  {'lang': 'ne',
#   'url': 'https://ne.wikipedia.org/wiki/%E0%A4%AC%E0%A4%BE%E0%A4%98'},
#  {'lang': 'new',
#   'url': 'https://new.wikipedia.org/wiki/%E0%A4%A7%E0%A5%81%E0%A4%81'},
#  {'lang': 'ja', 'url': 'https://ja.wikipedia.org/wiki/%E3%83%88%E3%83%A9'},
#  {'lang': 'ce',
#   'url': 'https://ce.wikipedia.org/wiki/%D0%A6%D3%80%D0%BE%D1%8C%D0%BA%D1%8A%D0%B0%D0%BB%D0%BE%D0%BC'},
#  {'lang': 'frr', 'url': 'https://frr.wikipedia.org/wiki/Tiiger'},
#  {'lang': 'no', 'url': 'https://no.wikipedia.org/wiki/Tiger'},
#  {'lang': 'nn', 'url': 'https://nn.wikipedia.org/wiki/Tiger'},
#  {'lang': 'oc', 'url': 'https://oc.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'or',
#   'url': 'https://or.wikipedia.org/wiki/%E0%AC%AC%E0%AC%BE%E0%AC%98'},
#  {'lang': 'om', 'url': 'https://om.wikipedia.org/wiki/Qeerransa'},
#  {'lang': 'uz', 'url': 'https://uz.wikipedia.org/wiki/Yo%CA%BBlbars'},
#  {'lang': 'pa',
#   'url': 'https://pa.wikipedia.org/wiki/%E0%A8%B8%E0%A8%BC%E0%A9%87%E0%A8%B0'},
#  {'lang': 'pnb', 'url': 'https://pnb.wikipedia.org/wiki/%D8%B4%DB%8C%D8%B1'},
#  {'lang': 'ps',
#   'url': 'https://ps.wikipedia.org/wiki/%D9%BE%DA%93%D8%A7%D9%86%DA%AF'},
#  {'lang': 'pl', 'url': 'https://pl.wikipedia.org/wiki/Tygrys_azjatycki'},
#  {'lang': 'pt', 'url': 'https://pt.wikipedia.org/wiki/Tigre'},
#  {'lang': 'kaa', 'url': 'https://kaa.wikipedia.org/wiki/Jolbar%C4%B1s'},
#  {'lang': 'ro', 'url': 'https://ro.wikipedia.org/wiki/Tigru'},
#  {'lang': 'qu', 'url': 'https://qu.wikipedia.org/wiki/Tikri'},
#  {'lang': 'ru',
#   'url': 'https://ru.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80'},
#  {'lang': 'sah',
#   'url': 'https://sah.wikipedia.org/wiki/%D0%91%D0%B0%D0%B0%D0%B1%D1%8B%D1%80'},
#  {'lang': 'szy', 'url': 'https://szy.wikipedia.org/wiki/lukedaw'},
#  {'lang': 'sm', 'url': 'https://sm.wikipedia.org/wiki/Taika'},
#  {'lang': 'sa',
#   'url': 'https://sa.wikipedia.org/wiki/%E0%A4%B5%E0%A5%8D%E0%A4%AF%E0%A4%BE%E0%A4%98%E0%A5%8D%E0%A4%B0%E0%A4%83'},
#  {'lang': 'sat',
#   'url': 'https://sat.wikipedia.org/wiki/%E1%B1%9B%E1%B1%9F%E1%B1%B9%E1%B1%A8%E1%B1%A9%E1%B1%B5'},
#  {'lang': 'skr', 'url': 'https://skr.wikipedia.org/wiki/%D8%B4%DB%8C%D8%B1'},
#  {'lang': 'sco', 'url': 'https://sco.wikipedia.org/wiki/Teeger'},
#  {'lang': 'sq', 'url': 'https://sq.wikipedia.org/wiki/Tigri'},
#  {'lang': 'scn', 'url': 'https://scn.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'si',
#   'url': 'https://si.wikipedia.org/wiki/%E0%B7%80%E0%B7%8A%E2%80%8D%E0%B6%BA%E0%B7%8F%E0%B6%9C%E0%B7%8A%E2%80%8D%E0%B6%BB%E0%B6%BA%E0%B7%8F'},
#  {'lang': 'simple', 'url': 'https://simple.wikipedia.org/wiki/Tiger'},
#  {'lang': 'sk',
#   'url': 'https://sk.wikipedia.org/wiki/Tiger_d%C5%BEung%C4%BEov%C3%BD'},
#  {'lang': 'sl', 'url': 'https://sl.wikipedia.org/wiki/Tiger'},
#  {'lang': 'cu',
#   'url': 'https://cu.wikipedia.org/wiki/%D0%A2%D1%97%D0%B3%D1%80%D1%8A'},
#  {'lang': 'szl', 'url': 'https://szl.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'so', 'url': 'https://so.wikipedia.org/wiki/Shabeel'},
#  {'lang': 'ckb',
#   'url': 'https://ckb.wikipedia.org/wiki/%D8%A8%DB%95%D9%88%D8%B1'},
#  {'lang': 'sr',
#   'url': 'https://sr.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D0%B0%D1%80'},
#  {'lang': 'sh', 'url': 'https://sh.wikipedia.org/wiki/Tigar'},
#  {'lang': 'su', 'url': 'https://su.wikipedia.org/wiki/Lodaya'},
#  {'lang': 'fi', 'url': 'https://fi.wikipedia.org/wiki/Tiikeri'},
#  {'lang': 'sv', 'url': 'https://sv.wikipedia.org/wiki/Tiger'},
#  {'lang': 'tl', 'url': 'https://tl.wikipedia.org/wiki/Tigre'},
#  {'lang': 'ta',
#   'url': 'https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%81%E0%AE%B2%E0%AE%BF'},
#  {'lang': 'kab', 'url': 'https://kab.wikipedia.org/wiki/Aksel_(a%C9%A3ersiw)'},
#  {'lang': 'tt',
#   'url': 'https://tt.wikipedia.org/wiki/%D0%AE%D0%BB%D0%B1%D0%B0%D1%80%D1%8B%D1%81'},
#  {'lang': 'shn',
#   'url': 'https://shn.wikipedia.org/wiki/%E1%80%9E%E1%80%AD%E1%80%B0%E1%80%9D%E1%80%BA'},
#  {'lang': 'tay', 'url': 'https://tay.wikipedia.org/wiki/kli%27'},
#  {'lang': 'te',
#   'url': 'https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%81%E0%B0%B2%E0%B0%BF'},
#  {'lang': 'th',
#   'url': 'https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%AA%E0%B8%B7%E0%B8%AD%E0%B9%82%E0%B8%84%E0%B8%A3%E0%B9%88%E0%B8%87'},
#  {'lang': 'tg',
#   'url': 'https://tg.wikipedia.org/wiki/%D0%91%D0%B0%D0%B1%D1%80'},
#  {'lang': 'chr',
#   'url': 'https://chr.wikipedia.org/wiki/%E1%8F%A2%E1%8F%93%E1%8F%A5%E1%8F%A7%E1%8E%B6%E1%8E%B8%E1%8F%97'},
#  {'lang': 'tcy',
#   'url': 'https://tcy.wikipedia.org/wiki/%E0%B2%AA%E0%B2%BF%E0%B2%B2%E0%B2%BF'},
#  {'lang': 'tr', 'url': 'https://tr.wikipedia.org/wiki/Kaplan'},
#  {'lang': 'tk', 'url': 'https://tk.wikipedia.org/wiki/Gapla%C5%88'},
#  {'lang': 'tw', 'url': 'https://tw.wikipedia.org/wiki/Seb%C9%94'},
#  {'lang': 'uk',
#   'url': 'https://uk.wikipedia.org/wiki/%D0%A2%D0%B8%D0%B3%D1%80'},
#  {'lang': 'ur', 'url': 'https://ur.wikipedia.org/wiki/%D8%B4%DB%8C%D8%B1'},
#  {'lang': 'ug',
#   'url': 'https://ug.wikipedia.org/wiki/%D8%A8%D8%A7%D8%B1%D8%B3'},
#  {'lang': 'za', 'url': 'https://za.wikipedia.org/wiki/Guk'},
#  {'lang': 'vep', 'url': 'https://vep.wikipedia.org/wiki/Tigr'},
#  {'lang': 'vi', 'url': 'https://vi.wikipedia.org/wiki/H%E1%BB%95'},
#  {'lang': 'fiu-vro', 'url': 'https://fiu-vro.wikipedia.org/wiki/Tiigri'},
#  {'lang': 'wa', 'url': 'https://wa.wikipedia.org/wiki/Tigue'},
#  {'lang': 'zh-classical',
#   'url': 'https://zh-classical.wikipedia.org/wiki/%E8%99%8E'},
#  {'lang': 'war', 'url': 'https://war.wikipedia.org/wiki/Panthera_tigris'},
#  {'lang': 'wo', 'url': 'https://wo.wikipedia.org/wiki/Segg'},
#  {'lang': 'wuu', 'url': 'https://wuu.wikipedia.org/wiki/%E8%99%8E'},
#  {'lang': 'yi',
#   'url': 'https://yi.wikipedia.org/wiki/%D7%98%D7%99%D7%92%D7%A2%D7%A8'},
#  {'lang': 'yo', 'url': 'https://yo.wikipedia.org/wiki/%E1%BA%B8k%C3%B9n'},
#  {'lang': 'zh-yue',
#   'url': 'https://zh-yue.wikipedia.org/wiki/%E8%80%81%E8%99%8E'},
#  {'lang': 'zh', 'url': 'https://zh.wikipedia.org/wiki/%E8%99%8E'},
#  {'lang': 'bbc', 'url': 'https://bbc.wikipedia.org/wiki/Babiat'}]

# %% [markdown]
# Repetition (dictionaries and loops): Now make a dictionary of all languages for which a Wikipedia page exists as well as the titles of these pages. Use the languages as keys and the titles as values (`{"English":"Tiger", ...}`). How are tigers called in `Finnish`?

# %%
[{"lang": link["lang"], "url": link["url"]} for link in data["langlinks"] if link["lang"] == "fi"]
# Out:
# [{'lang': 'fi', 'url': 'https://fi.wikipedia.org/wiki/Tiikeri'}]

# %% [markdown]
# ### Exercise 1.2

# %% [markdown]
# Find the HTML text within the structured data on the tiger page and assign it to a variable named ``htmlText``.

# %% [markdown]
# Convert the string to a BeautifulSoup object and assign it to a variable called ``tigerSoup``.

# %% [markdown]
# Repetitition: Extract (1) the first table and (2) the third paragraph of the article.

# %% [markdown]
# ### Exercise 1.3

# %% [markdown]
# Retrieve the information about 10 Wikipedia pages that match with the word "tiger" and convert the response to a dictionary. ><font color='violet'> Hint: <font color='white'> Hint: The "srlimit" parameter allows you to specify how many pages you want to retrieve.

# %% [markdown]
# Navigate through the dictionary or type the URL into your browser to inspect how the data is structured.

# %% [markdown]
# Now print out the titles of the 10 tiger pages.

# %% [markdown]
# ### Exercise 1.4

# %% [markdown]
# In the web scraping exercises, you wrote a simple scraper that fetched you some information from the following animal pages:

# %%
animals = ["Cat", "Dog", "Tiger", "Giant_panda"]

# %% [markdown]
# You will now try to do the same using the API: Write a loop that fetches all the pages and retrieves (1) the title and (2) the number of images on each page.

# %% [markdown]
# Let's do this step by step. First try to fetch the "Cat" page and convert the JSON response you get into a Python dictionary.

# %% [markdown]
# Now try to retrieve the title and the number of images. Assign each of them to a variable.

# %% [markdown]
# Now write a loop that fetches all the pages and writes the response into a list. You will have to create an empty list and ``append`` the new elements to it:

# %% [markdown]
# Finally, you can bring everything together. Improve your loop so that it parses each page, retrieves the title and the number of images and writes them into a nested list.

# %% [markdown]
# ## 2. Advanced exercises*

# %% [markdown]
# ---
#
#
# <font color='red'>
# *Feel free to skip the advanced exercises if you feel overwhelmed or if trying to solve the basic exercises already took you a lot of time!
#
#
# ---

# %% [markdown]
# ### Exercise 2.1

# %% [markdown]
# Write a function called ``getWiki`` that allows you to enter the name of a Wikipedia page and returns the parsed JSON response as a Python dictionary.

# %% [markdown]
# ### Exercise 2.2

# %% [markdown]
# You would like to know if Zürich or Bern is more popular on Wikipedia. For this purpose, you will measure (1) the number of Wikipedia articles within a 1km-radius around the train station and (2) the total number of images in these articles. Try to work with functions instead of copying and pasting code!
#
# You can take the following coordinates:
# * Bern: 46.949722, 7.439444
# * Zürich: 47.377455, 8.539688

# %% [markdown]
# Start by comparing the number of articles:

# %% [markdown]
# Now try to compare the total number of images in these articles. You will have to write a loop to retrieve each page.
