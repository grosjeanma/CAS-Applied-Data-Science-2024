# %% [markdown]
# ## Tutorial II: Optimization in **pytorch** and NN introduction
#
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# time to teach without exercises 50mins

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## 2. Linear fit
#
# Here we will solve optimization problem to perform linear regression. First we will generate training set of 80 data points and test set of 20, laying on a line with a random offset $$y = a_0 x + b_0 + \delta,$$ where $\delta$ is a random variable sampled from a uniform distribution with standard deviation equal to $s_0$.
# <!-- o.f.: 46, 48, 87, 99 | val better than train: 47, 56, 86. -->

# %%
a0 = 3  # 3
b0 = 5  # 5
s0 = 1  # 1

n_all = 100

np.random.seed(99)

# all samples
x_all = np.linspace(0, 10, n_all)  # 100 points
d_all = np.random.uniform(-s0, s0, size=n_all)
y_all = np.asarray([a0*x + b0 + d for x, d in zip(x_all, d_all)])

# randomize order and get 80% for training
idx = np.random.permutation(n_all)
n_train = n_all * 80 // 100

idx_train = idx[0:n_train]
idx_val = idx[n_train:]

x_train, y_train = x_all[idx_train], y_all[idx_train]

x_val, y_val = x_all[idx_val], y_all[idx_val]

plt.plot(x_train, y_train, "or", x_val, y_val, "b^")
plt.legend(('training points', 'validation points'),  loc='upper left');

# %% [markdown]
# We will then define loss function as the mean of squared residuals (distance from line along $y$) for the points.
#
# We will use [stochactic gradient descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent): on each iteration use only a fraction (`batch_size`) of all training set. In many cases training set is huge and cannot be fed on each iteration in principle. Also it can sometimes help the optimizer to properly explore the manifold.

# %%
class Linear(nn.Module):
    def __init__(self):
        super(Linear, self).__init__()
        self.a = nn.Parameter(torch.randn(1, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.a * x + self.b


def loss_f(true_y, y_predicted):
    return F.mse_loss(y_predicted, true_y)

# %%
len(x_train)
# Out:
# 80

# %%
# Define the model
model = Linear()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.001)

# Define the number of epochs and batch size
epochs = 400
batch_size = 10


x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
y_train = torch.tensor(y_train)

x_val = torch.tensor(x_val)
y_val = torch.tensor(y_val)



# Training loop
train_loss_history = []
val_loss_history = []
for epoch in range(epochs):
    model.train()  # as opposed to model.eval()
    batch_losses = []
    permutation = torch.randperm(x_train.size()[0])


    for i in range(0, x_train.size()[0], batch_size):
        optimizer.zero_grad()

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = x_train[indices], y_train[indices]

        # Forward pass
        outputs = model(batch_x)

        # Compute the loss
        loss = loss_f(batch_y, outputs)
        batch_losses.append(loss.item())
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    average_training_loss = np.mean(batch_losses)
    train_loss_history.append(average_training_loss)

    # Validation step (optional, for monitoring performance)
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = loss_f(y_val, val_outputs)
        val_loss_history.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss.item()}")
# Out:
# /var/folders/vt/ylsvf5fn1d7_gznl9zf0z0tr0000gn/T/ipykernel_84656/3723866347.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
# /var/folders/vt/ylsvf5fn1d7_gznl9zf0z0tr0000gn/T/ipykernel_84656/3723866347.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train)
# /var/folders/vt/ylsvf5fn1d7_gznl9zf0z0tr0000gn/T/ipykernel_84656/3723866347.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_val = torch.tensor(x_val)
# /var/folders/vt/ylsvf5fn1d7_gznl9zf0z0tr0000gn/T/ipykernel_84656/3723866347.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val)
# Epoch 1/400, Validation Loss: 100.66208801140968
# Epoch 2/400, Validation Loss: 33.76411139438604
# Epoch 3/400, Validation Loss: 12.510139682056934
# Epoch 4/400, Validation Loss: 5.811262572387894
# Epoch 5/400, Validation Loss: 3.776743538823471
# Epoch 6/400, Validation Loss: 3.106116860697832
# Epoch 7/400, Validation Loss: 2.9149079502185873
# Epoch 8/400, Validation Loss: 2.848854660702873
# Epoch 9/400, Validation Loss: 2.8153200454134555
# Epoch 10/400, Validation Loss: 2.7927830734642365
# Epoch 11/400, Validation Loss: 2.773678114920873
# Epoch 12/400, Validation Loss: 2.752160033190567
# Epoch 13/400, Validation Loss: 2.7339560703411747
# Epoch 14/400, Validation Loss: 2.7126700937059303
# Epoch 15/400, Validation Loss: 2.6951149525361595
# Epoch 16/400, Validation Loss: 2.6711565023516584
# Epoch 17/400, Validation Loss: 2.6516870781839113
# Epoch 18/400, Validation Loss: 2.6324358084123864
# Epoch 19/400, Validation Loss: 2.611542637019093
# Epoch 20/400, Validation Loss: 2.590359937019464
# Epoch 21/400, Validation Loss: 2.569828963000665
# Epoch 22/400, Validation Loss: 2.5481752416523404
# Epoch 23/400, Validation Loss: 2.5316147153638697
# Epoch 24/400, Validation Loss: 2.5111613161372035
# Epoch 25/400, Validation Loss: 2.494429259438703
# Epoch 26/400, Validation Loss: 2.4760386454310557
# Epoch 27/400, Validation Loss: 2.4581306741358113
# Epoch 28/400, Validation Loss: 2.437358325138155
# Epoch 29/400, Validation Loss: 2.4206263814041464
# Epoch 30/400, Validation Loss: 2.4043896515443577
# Epoch 31/400, Validation Loss: 2.384815993502717
# Epoch 32/400, Validation Loss: 2.365828648445941
# Epoch 33/400, Validation Loss: 2.348200724670448
# Epoch 34/400, Validation Loss: 2.3312481984876205
# Epoch 35/400, Validation Loss: 2.311473510681501
# Epoch 36/400, Validation Loss: 2.295417051053545
# Epoch 37/400, Validation Loss: 2.2787855001420523
# Epoch 38/400, Validation Loss: 2.2629606315516866
# Epoch 39/400, Validation Loss: 2.244046346264792
# Epoch 40/400, Validation Loss: 2.228934673061723
# Epoch 41/400, Validation Loss: 2.210065510616206
# Epoch 42/400, Validation Loss: 2.1927690752016824
# Epoch 43/400, Validation Loss: 2.1776958569197156
# Epoch 44/400, Validation Loss: 2.1595705568744483
# Epoch 45/400, Validation Loss: 2.1457836549342404
# Epoch 46/400, Validation Loss: 2.126039039840699
# Epoch 47/400, Validation Loss: 2.111807683941913
# Epoch 48/400, Validation Loss: 2.0938429981311772
# Epoch 49/400, Validation Loss: 2.080785260129827
# Epoch 50/400, Validation Loss: 2.067264793656926
# Epoch 51/400, Validation Loss: 2.050183026122606
# Epoch 52/400, Validation Loss: 2.03658995069899
# Epoch 53/400, Validation Loss: 2.0210166753337
# Epoch 54/400, Validation Loss: 2.0064200672416908
# Epoch 55/400, Validation Loss: 1.992974085187731
# Epoch 56/400, Validation Loss: 1.9780398181940868
# Epoch 57/400, Validation Loss: 1.9617281431079463
# Epoch 58/400, Validation Loss: 1.945814131493277
# Epoch 59/400, Validation Loss: 1.9330801987573054
# Epoch 60/400, Validation Loss: 1.9191414872775403
# Epoch 61/400, Validation Loss: 1.9047663202765037
# Epoch 62/400, Validation Loss: 1.8908193039130072
# Epoch 63/400, Validation Loss: 1.8768825429942897
# Epoch 64/400, Validation Loss: 1.8646745345452953
# Epoch 65/400, Validation Loss: 1.851831858167926
# Epoch 66/400, Validation Loss: 1.8387096076004135
# Epoch 67/400, Validation Loss: 1.8253160495386531
# Epoch 68/400, Validation Loss: 1.8146057690749338
# Epoch 69/400, Validation Loss: 1.7997987002550153
# Epoch 70/400, Validation Loss: 1.7858537633024074
# Epoch 71/400, Validation Loss: 1.7720466907466665
# Epoch 72/400, Validation Loss: 1.7587644797151167
# Epoch 73/400, Validation Loss: 1.7468151267215664
# Epoch 74/400, Validation Loss: 1.7340920602005219
# Epoch 75/400, Validation Loss: 1.7215044507990922
# Epoch 76/400, Validation Loss: 1.7088010912240723
# Epoch 77/400, Validation Loss: 1.6953705598230786
# Epoch 78/400, Validation Loss: 1.6851136263267676
# Epoch 79/400, Validation Loss: 1.672431046642712
# Epoch 80/400, Validation Loss: 1.6610436745983175
# Epoch 81/400, Validation Loss: 1.649719877797367
# Epoch 82/400, Validation Loss: 1.6382946994613143
# Epoch 83/400, Validation Loss: 1.6253707048107937
# Epoch 84/400, Validation Loss: 1.614925931387095
# Epoch 85/400, Validation Loss: 1.6031665222853797
# Epoch 86/400, Validation Loss: 1.5951969661841732
# Epoch 87/400, Validation Loss: 1.5856163112550063
# Epoch 88/400, Validation Loss: 1.5682321208322383
# Epoch 89/400, Validation Loss: 1.558267532029276
# Epoch 90/400, Validation Loss: 1.5503075108445605
# Epoch 91/400, Validation Loss: 1.5365254902106475
# Epoch 92/400, Validation Loss: 1.5231113448373685
# Epoch 93/400, Validation Loss: 1.5166676991177943
# Epoch 94/400, Validation Loss: 1.5052904834270977
# Epoch 95/400, Validation Loss: 1.4963380565115427
# Epoch 96/400, Validation Loss: 1.4847888986872124
# Epoch 97/400, Validation Loss: 1.4745417638179537
# Epoch 98/400, Validation Loss: 1.462808055953517
# Epoch 99/400, Validation Loss: 1.4529951274614503
# Epoch 100/400, Validation Loss: 1.4442346723010924
# Epoch 101/400, Validation Loss: 1.4324110319085637
# Epoch 102/400, Validation Loss: 1.4233755548861984
# Epoch 103/400, Validation Loss: 1.4125089739863996
# Epoch 104/400, Validation Loss: 1.402949966027927
# Epoch 105/400, Validation Loss: 1.396140854302324
# Epoch 106/400, Validation Loss: 1.3881727704416646
# Epoch 107/400, Validation Loss: 1.3794214388509736
# Epoch 108/400, Validation Loss: 1.3678441428025738
# Epoch 109/400, Validation Loss: 1.3580860035103168
# Epoch 110/400, Validation Loss: 1.3512134641384643
# Epoch 111/400, Validation Loss: 1.3391277019891512
# Epoch 112/400, Validation Loss: 1.3308979994164423
# Epoch 113/400, Validation Loss: 1.3231018440296753
# Epoch 114/400, Validation Loss: 1.315416716526628
# Epoch 115/400, Validation Loss: 1.307322871031318
# Epoch 116/400, Validation Loss: 1.3018772091766917
# Epoch 117/400, Validation Loss: 1.2906395758761222
# Epoch 118/400, Validation Loss: 1.2784911548296907
# Epoch 119/400, Validation Loss: 1.2700813667028499
# Epoch 120/400, Validation Loss: 1.264929102673945
# Epoch 121/400, Validation Loss: 1.2569463777635286
# Epoch 122/400, Validation Loss: 1.2474931269823857
# Epoch 123/400, Validation Loss: 1.2389400054869637
# Epoch 124/400, Validation Loss: 1.2316358869431292
# Epoch 125/400, Validation Loss: 1.2231752802297025
# Epoch 126/400, Validation Loss: 1.2157684604237007
# Epoch 127/400, Validation Loss: 1.2079310750358876
# Epoch 128/400, Validation Loss: 1.2003385321156776
# Epoch 129/400, Validation Loss: 1.1957181994319015
# Epoch 130/400, Validation Loss: 1.1857159933902803
# Epoch 131/400, Validation Loss: 1.1749912110462486
# Epoch 132/400, Validation Loss: 1.1690184502598673
# Epoch 133/400, Validation Loss: 1.1592336912956749
# Epoch 134/400, Validation Loss: 1.1547046588890804
# Epoch 135/400, Validation Loss: 1.1467549152142058
# Epoch 136/400, Validation Loss: 1.139665164928265
# Epoch 137/400, Validation Loss: 1.1340716621946272
# Epoch 138/400, Validation Loss: 1.1277748672629602
# Epoch 139/400, Validation Loss: 1.120828553418057
# Epoch 140/400, Validation Loss: 1.1117771102442984
# Epoch 141/400, Validation Loss: 1.1050327443777033
# Epoch 142/400, Validation Loss: 1.1021787152382096
# Epoch 143/400, Validation Loss: 1.090458509458513
# Epoch 144/400, Validation Loss: 1.0847707973669007
# Epoch 145/400, Validation Loss: 1.078845147002306
# Epoch 146/400, Validation Loss: 1.071246914405771
# Epoch 147/400, Validation Loss: 1.0633573021580058
# Epoch 148/400, Validation Loss: 1.0586100235640608
# Epoch 149/400, Validation Loss: 1.0511487770511856
# Epoch 150/400, Validation Loss: 1.0442939971312106
# Epoch 151/400, Validation Loss: 1.039444471431733
# Epoch 152/400, Validation Loss: 1.0315133007879758
# Epoch 153/400, Validation Loss: 1.023241044306646
# Epoch 154/400, Validation Loss: 1.0154923162611236
# Epoch 155/400, Validation Loss: 1.0104274450889448
# Epoch 156/400, Validation Loss: 1.008392151156399
# Epoch 157/400, Validation Loss: 1.0027615092584572
# Epoch 158/400, Validation Loss: 0.9963137910194589
# Epoch 159/400, Validation Loss: 0.9893720828065071
# Epoch 160/400, Validation Loss: 0.9825401631252124
# Epoch 161/400, Validation Loss: 0.9772027681915463
# Epoch 162/400, Validation Loss: 0.9719757879982549
# Epoch 163/400, Validation Loss: 0.9666892228234942
# Epoch 164/400, Validation Loss: 0.9602110959436929
# Epoch 165/400, Validation Loss: 0.9561481666412479
# Epoch 166/400, Validation Loss: 0.9492857018689236
# Epoch 167/400, Validation Loss: 0.9470121825587704
# Epoch 168/400, Validation Loss: 0.9400692004514436
# Epoch 169/400, Validation Loss: 0.9343099749328285
# Epoch 170/400, Validation Loss: 0.9304328699041738
# Epoch 171/400, Validation Loss: 0.9244578932137364
# Epoch 172/400, Validation Loss: 0.9179870506628205
# Epoch 173/400, Validation Loss: 0.9113131643858307
# Epoch 174/400, Validation Loss: 0.9072606282318955
# Epoch 175/400, Validation Loss: 0.9024933086904632
# Epoch 176/400, Validation Loss: 0.8971356045745231
# Epoch 177/400, Validation Loss: 0.8925518604796213
# Epoch 178/400, Validation Loss: 0.8874072795799293
# Epoch 179/400, Validation Loss: 0.8824782973197625
# Epoch 180/400, Validation Loss: 0.8775324910947397
# Epoch 181/400, Validation Loss: 0.8721636521704808
# Epoch 182/400, Validation Loss: 0.8697887038212062
# Epoch 183/400, Validation Loss: 0.8642901680346625
# Epoch 184/400, Validation Loss: 0.8603527827956594
# Epoch 185/400, Validation Loss: 0.8562941192241361
# Epoch 186/400, Validation Loss: 0.8480363521035639
# Epoch 187/400, Validation Loss: 0.8442772183402892
# Epoch 188/400, Validation Loss: 0.8405098825594367
# Epoch 189/400, Validation Loss: 0.8350568909018279
# Epoch 190/400, Validation Loss: 0.830555479842112
# Epoch 191/400, Validation Loss: 0.8269119536225826
# Epoch 192/400, Validation Loss: 0.8219732867149693
# Epoch 193/400, Validation Loss: 0.8179424203256861
# Epoch 194/400, Validation Loss: 0.8137892329151445
# Epoch 195/400, Validation Loss: 0.8095720264751474
# Epoch 196/400, Validation Loss: 0.8060595379371849
# Epoch 197/400, Validation Loss: 0.8007739721625612
# Epoch 198/400, Validation Loss: 0.7986321414618657
# Epoch 199/400, Validation Loss: 0.7928004079294088
# Epoch 200/400, Validation Loss: 0.7909173367879667
# Epoch 201/400, Validation Loss: 0.7857100460979702
# Epoch 202/400, Validation Loss: 0.7809467079385488
# Epoch 203/400, Validation Loss: 0.781340447671605
# Epoch 204/400, Validation Loss: 0.7765962905112185
# Epoch 205/400, Validation Loss: 0.7732166507434108
# Epoch 206/400, Validation Loss: 0.7690560280446486
# Epoch 207/400, Validation Loss: 0.7637434366857505
# Epoch 208/400, Validation Loss: 0.76169063789085
# Epoch 209/400, Validation Loss: 0.7591577346872614
# Epoch 210/400, Validation Loss: 0.7546420270217815
# Epoch 211/400, Validation Loss: 0.7522152089891662
# Epoch 212/400, Validation Loss: 0.7456373936343045
# Epoch 213/400, Validation Loss: 0.7432319417649502
# Epoch 214/400, Validation Loss: 0.7384103800068414
# Epoch 215/400, Validation Loss: 0.7329423990978283
# Epoch 216/400, Validation Loss: 0.7296395631330261
# Epoch 217/400, Validation Loss: 0.7273919802312047
# Epoch 218/400, Validation Loss: 0.7237493471115558
# Epoch 219/400, Validation Loss: 0.7199304703413573
# Epoch 220/400, Validation Loss: 0.7175355140006807
# Epoch 221/400, Validation Loss: 0.7137295650820479
# Epoch 222/400, Validation Loss: 0.711399951928664
# Epoch 223/400, Validation Loss: 0.7076611847017208
# Epoch 224/400, Validation Loss: 0.7023459614826857
# Epoch 225/400, Validation Loss: 0.7001536217116667
# Epoch 226/400, Validation Loss: 0.6969107186728583
# Epoch 227/400, Validation Loss: 0.6953344456536442
# Epoch 228/400, Validation Loss: 0.6907319955823297
# Epoch 229/400, Validation Loss: 0.6874649211796574
# Epoch 230/400, Validation Loss: 0.6857581437165859
# Epoch 231/400, Validation Loss: 0.6827154332448724
# Epoch 232/400, Validation Loss: 0.6783348787585697
# Epoch 233/400, Validation Loss: 0.6765019012071898
# Epoch 234/400, Validation Loss: 0.6731606874874635
# Epoch 235/400, Validation Loss: 0.6712166239386554
# Epoch 236/400, Validation Loss: 0.6667982545435264
# Epoch 237/400, Validation Loss: 0.6650689199058065
# Epoch 238/400, Validation Loss: 0.6622534130042161
# Epoch 239/400, Validation Loss: 0.6591911731108471
# Epoch 240/400, Validation Loss: 0.6593292786652484
# Epoch 241/400, Validation Loss: 0.6545607303550447
# Epoch 242/400, Validation Loss: 0.6507565202866822
# Epoch 243/400, Validation Loss: 0.6470263602283175
# Epoch 244/400, Validation Loss: 0.6465879244236378
# Epoch 245/400, Validation Loss: 0.6442790150788764
# Epoch 246/400, Validation Loss: 0.6417162950280851
# Epoch 247/400, Validation Loss: 0.6378952246891509
# Epoch 248/400, Validation Loss: 0.636435940465572
# Epoch 249/400, Validation Loss: 0.6315490850834793
# Epoch 250/400, Validation Loss: 0.6296631806533173
# Epoch 251/400, Validation Loss: 0.6292298843057305
# Epoch 252/400, Validation Loss: 0.6247765478659478
# Epoch 253/400, Validation Loss: 0.6221031516789944
# Epoch 254/400, Validation Loss: 0.6197517983713867
# Epoch 255/400, Validation Loss: 0.6183714533635652
# Epoch 256/400, Validation Loss: 0.6157117300196652
# Epoch 257/400, Validation Loss: 0.6147032855790839
# Epoch 258/400, Validation Loss: 0.6123394207023901
# Epoch 259/400, Validation Loss: 0.6099358490441087
# Epoch 260/400, Validation Loss: 0.6058592286432212
# Epoch 261/400, Validation Loss: 0.6037438362402597
# Epoch 262/400, Validation Loss: 0.6047699695711765
# Epoch 263/400, Validation Loss: 0.6016183657303397
# Epoch 264/400, Validation Loss: 0.5991851105505641
# Epoch 265/400, Validation Loss: 0.5963670479855119
# Epoch 266/400, Validation Loss: 0.5946028174192419
# Epoch 267/400, Validation Loss: 0.5926864918379314
# Epoch 268/400, Validation Loss: 0.5912251618722848
# Epoch 269/400, Validation Loss: 0.5905924048208836
# Epoch 270/400, Validation Loss: 0.585971934685767
# Epoch 271/400, Validation Loss: 0.5834627199896322
# Epoch 272/400, Validation Loss: 0.5797108035247979
# Epoch 273/400, Validation Loss: 0.5788981507833687
# Epoch 274/400, Validation Loss: 0.5768975473165948
# Epoch 275/400, Validation Loss: 0.574555158833147
# Epoch 276/400, Validation Loss: 0.5743860055217505
# Epoch 277/400, Validation Loss: 0.5743198532339728
# Epoch 278/400, Validation Loss: 0.5714724058812841
# Epoch 279/400, Validation Loss: 0.5712600984895062
# Epoch 280/400, Validation Loss: 0.5669406315661366
# Epoch 281/400, Validation Loss: 0.5653900395645256
# Epoch 282/400, Validation Loss: 0.5633966023363671
# Epoch 283/400, Validation Loss: 0.5623112167505964
# Epoch 284/400, Validation Loss: 0.5598343608031127
# Epoch 285/400, Validation Loss: 0.556525621332804
# Epoch 286/400, Validation Loss: 0.5546082787498556
# Epoch 287/400, Validation Loss: 0.553036696476265
# Epoch 288/400, Validation Loss: 0.5515448859645758
# Epoch 289/400, Validation Loss: 0.5498891656704125
# Epoch 290/400, Validation Loss: 0.5481431266572736
# Epoch 291/400, Validation Loss: 0.5468958045843794
# Epoch 292/400, Validation Loss: 0.546236522400451
# Epoch 293/400, Validation Loss: 0.5438511714776036
# Epoch 294/400, Validation Loss: 0.5442265395500427
# Epoch 295/400, Validation Loss: 0.5430155202183898
# Epoch 296/400, Validation Loss: 0.5400161037434443
# Epoch 297/400, Validation Loss: 0.5412110103991168
# Epoch 298/400, Validation Loss: 0.5366469332990611
# Epoch 299/400, Validation Loss: 0.5356274459077385
# Epoch 300/400, Validation Loss: 0.5331939746625698
# Epoch 301/400, Validation Loss: 0.5301826053966128
# Epoch 302/400, Validation Loss: 0.5294908796950366
# Epoch 303/400, Validation Loss: 0.5293384129141854
# Epoch 304/400, Validation Loss: 0.5273865461764963
# Epoch 305/400, Validation Loss: 0.5249520872119404
# Epoch 306/400, Validation Loss: 0.523467209628744
# Epoch 307/400, Validation Loss: 0.5234064817355474
# Epoch 308/400, Validation Loss: 0.5209457244039026
# Epoch 309/400, Validation Loss: 0.5198143963555995
# Epoch 310/400, Validation Loss: 0.5179873693873356
# Epoch 311/400, Validation Loss: 0.5154253867978447
# Epoch 312/400, Validation Loss: 0.5149336095099647
# Epoch 313/400, Validation Loss: 0.5154953377904551
# Epoch 314/400, Validation Loss: 0.5138683844827063
# Epoch 315/400, Validation Loss: 0.5115542994792233
# Epoch 316/400, Validation Loss: 0.5087346205229887
# Epoch 317/400, Validation Loss: 0.509636240964513
# Epoch 318/400, Validation Loss: 0.5086818115157842
# Epoch 319/400, Validation Loss: 0.50815199979053
# Epoch 320/400, Validation Loss: 0.5049832840735574
# Epoch 321/400, Validation Loss: 0.5049699700960399
# Epoch 322/400, Validation Loss: 0.5028467220343723
# Epoch 323/400, Validation Loss: 0.5027107635180963
# Epoch 324/400, Validation Loss: 0.5003152148845889
# Epoch 325/400, Validation Loss: 0.5015793181890886
# Epoch 326/400, Validation Loss: 0.5010525209962086
# Epoch 327/400, Validation Loss: 0.49994508093044326
# Epoch 328/400, Validation Loss: 0.49887075856096247
# Epoch 329/400, Validation Loss: 0.4994104374940723
# Epoch 330/400, Validation Loss: 0.4982376112823461
# Epoch 331/400, Validation Loss: 0.49715496379795854
# Epoch 332/400, Validation Loss: 0.49424962037853304
# Epoch 333/400, Validation Loss: 0.4946819246238059
# Epoch 334/400, Validation Loss: 0.4921273022540281
# Epoch 335/400, Validation Loss: 0.49048920682638286
# Epoch 336/400, Validation Loss: 0.48997526233492916
# Epoch 337/400, Validation Loss: 0.4877556362981645
# Epoch 338/400, Validation Loss: 0.4871283679476826
# Epoch 339/400, Validation Loss: 0.486203001834303
# Epoch 340/400, Validation Loss: 0.4843810569959947
# Epoch 341/400, Validation Loss: 0.482096971536434
# Epoch 342/400, Validation Loss: 0.48026731685849733
# Epoch 343/400, Validation Loss: 0.48066316133760145
# Epoch 344/400, Validation Loss: 0.4779150478366295
# Epoch 345/400, Validation Loss: 0.4767835737377718
# Epoch 346/400, Validation Loss: 0.47785943328597175
# Epoch 347/400, Validation Loss: 0.47691452961904457
# Epoch 348/400, Validation Loss: 0.47513511751776
# Epoch 349/400, Validation Loss: 0.4744453902889898
# Epoch 350/400, Validation Loss: 0.4733544571312526
# Epoch 351/400, Validation Loss: 0.47361050867125626
# Epoch 352/400, Validation Loss: 0.47385696377746694
# Epoch 353/400, Validation Loss: 0.4726382801403249
# Epoch 354/400, Validation Loss: 0.4695734157769714
# Epoch 355/400, Validation Loss: 0.46824230902980163
# Epoch 356/400, Validation Loss: 0.4667450832376906
# Epoch 357/400, Validation Loss: 0.46614650106629585
# Epoch 358/400, Validation Loss: 0.46580192694681666
# Epoch 359/400, Validation Loss: 0.46514669387980756
# Epoch 360/400, Validation Loss: 0.4658655161423663
# Epoch 361/400, Validation Loss: 0.46472386570744995
# Epoch 362/400, Validation Loss: 0.46432722084371714
# Epoch 363/400, Validation Loss: 0.46470881519858426
# Epoch 364/400, Validation Loss: 0.46309198605829804
# Epoch 365/400, Validation Loss: 0.4611955402502509
# Epoch 366/400, Validation Loss: 0.4587759054788503
# Epoch 367/400, Validation Loss: 0.4593164449863202
# Epoch 368/400, Validation Loss: 0.4587280875375761
# Epoch 369/400, Validation Loss: 0.4574395351599458
# Epoch 370/400, Validation Loss: 0.45757465531856967
# Epoch 371/400, Validation Loss: 0.45714281953859903
# Epoch 372/400, Validation Loss: 0.4560681225112256
# Epoch 373/400, Validation Loss: 0.4562082625692028
# Epoch 374/400, Validation Loss: 0.45552003729643903
# Epoch 375/400, Validation Loss: 0.45411984743058487
# Epoch 376/400, Validation Loss: 0.45436201949426314
# Epoch 377/400, Validation Loss: 0.4539584811853257
# Epoch 378/400, Validation Loss: 0.4531835202821483
# Epoch 379/400, Validation Loss: 0.45333043499621006
# Epoch 380/400, Validation Loss: 0.4537036346689226
# Epoch 381/400, Validation Loss: 0.4512596615968071
# Epoch 382/400, Validation Loss: 0.45129667870123463
# Epoch 383/400, Validation Loss: 0.44951909043037014
# Epoch 384/400, Validation Loss: 0.4487858986482438
# Epoch 385/400, Validation Loss: 0.4497098118053263
# Epoch 386/400, Validation Loss: 0.4487202367327642
# Epoch 387/400, Validation Loss: 0.44807722217660634
# Epoch 388/400, Validation Loss: 0.44722201246186694
# Epoch 389/400, Validation Loss: 0.4470393646715952
# Epoch 390/400, Validation Loss: 0.44716784292813383
# Epoch 391/400, Validation Loss: 0.44640558869553415
# Epoch 392/400, Validation Loss: 0.4469063291562164
# Epoch 393/400, Validation Loss: 0.44499958739469553
# Epoch 394/400, Validation Loss: 0.44288152833099625
# Epoch 395/400, Validation Loss: 0.4438011814798344
# Epoch 396/400, Validation Loss: 0.4421305269139955
# Epoch 397/400, Validation Loss: 0.44224834280444225
# Epoch 398/400, Validation Loss: 0.44183261771657845
# Epoch 399/400, Validation Loss: 0.4441138699439534
# Epoch 400/400, Validation Loss: 0.43984446080036255

# %%
a_val, b_val = model.a.item(), model.b.item()

# Generate predictions for plotting
end_fit_x = [x_all[0], x_all[-1]]
end_fit_y = [a_val * x + b_val for x in end_fit_x]
true_fn_y = [a0 * x + b0 for x in end_fit_x]  # Assuming a0 and b0 are known true values

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plotting data points and model predictions
axs[0].plot(x_train, y_train, 'ro', x_val, y_val, 'b^', end_fit_x, end_fit_y, 'g')
axs[0].legend(('training points', 'test points', 'final fit'), loc='upper left')

# Assuming training and validation loss history are stored in lists: train_loss_history and val_loss_history
epochs = range(1, len(train_loss_history) + 1)

# Plotting loss history
axs[1].semilogy(epochs, train_loss_history, 'r')
axs[1].semilogy(epochs, val_loss_history, 'b')
axs[1].legend(('training loss', 'validation loss'), loc='upper right')

plt.show()

# %% [markdown]
# ## 3. Exercise 1
#
# Play with the true function parameters ```a0, b0, s0``` and the ``batch_size`` value, check how it affects the convergence.
#
# 1. How change of `s0` affects convergance?
# 2. When one should stop training to prevent overfitting?
#
#
# ## 4. Training loop
#
# The training as we just saw is done iteratively, by adjusting the model parameters.
#
# We perform optimization several times for all traininng dataset. Going through all this dataset is refered to as 'epoch'.
#
# When we do training its usually done in two loops. In outer loop we iterate over all epochs. For each epoch we usually split the dataset into small chuncks, batches, and optimization it performed for all of those.
#
# It is important that data doesn't go to the training pipeline in same order. So the overall scheme looks like this (pseudocode):
#
#
# ```
# x,y = get_training_data()
# for epoch in range(number_epochs):
#    x_shfl,y_shfl = shuffle(x,y)
#
#    for mb_idx in range(number_minibatches_in_batch):
#        x_mb,y_mb = get_minibatch(x_shfl,y_shfl, mb_idx)
#
#        optimize_on(data=x_mb, labels=y_mb)
# ```
#
# ## 5. Bulding blocks of a neural network
#
# Neural network consists of layers of neurons. Each neuron perfroms 2 operations.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/Perceptron.png" alt="drawing" width="30%"/>
#
# Each neuron performs 2 operations.
#
# 1. Calculate the linear transformation of the input vector $\mathbf{x}_i$:
# $$z_i = \mathbf{w} \cdot \mathbf{x}_i + b = \sum_j {w_j x_{ij}} + b$$ where $\mathbf{w}$ is a weight vector and $b$ - a bias, and $j$ traverses each dimension of the input vector
# 2. Perform the nonlinear transformation of the result using the activation function $f$ $$y_i = f(z_i)$$
#
# In a fully connected neural network, each layer is a set of N neurons, performing different transformations of the input $\mathbf{x}_i$ of the same layer, now producing an output **vector** $ \mathbf{y} _i = f(\mathbf{z}_i) = f(W\mathbf{x}_i + \mathbf{b})$ now with a bias vector $\mathbf{b}$ and a * *matrix** of weights $W$.
#
# Since the output of each layer constitutes the input to the next layer, we can write for layer $l$: $$\mathbf{x}^l_i = f^{l-1}(\mathbf{W}^{ l-1} \mathbf{x}^{ l-1}_i + \mathbf{b}^{l-1})$$ where $\mathbf{x}_i^{l=0}$ is the vector d 'network input for data point $i$.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/MLP.png" alt="drawing" width="50%"/>
#
# To simplify building the network, we'll define a helper function, creating neuron layer with given number of outputs:

# %%
class Dense(nn.Module):
    def __init__(self, input_units, output_units, activation=None):
        """
        Fully connected layer implemented with explicit matrix multiplication.

        Parameters
        ----------
        input_units : int
            Number of input neurons
        output_units : int
            Number of output neurons
        activation : callable or None, optional
            Non-linear activation function (e.g., F.relu)
        """
        super(Dense, self).__init__()
        self.input_units = int(input_units)
        self.output_units = int(output_units)
        self.activation = activation

        # Initialize weights and biases
        self.weights = nn.Parameter(torch.randn(input_units, output_units))
        self.bias = nn.Parameter(torch.randn(output_units))

    def forward(self, x):
        """
        Forward pass through the layer.

        Parameters
        ----------
        x : torch.Tensor
            Input tensor

        Returns
        -------
        torch.Tensor
            Output of the layer
        """

        outputs = torch.matmul(x, self.weights) + self.bias

        # Apply activation function if provided
        if self.activation is not None:
            # Check if the activation function is softmax
            if self.activation == F.softmax:
                # Apply softmax with specified dimension
                outputs = self.activation(outputs, dim=1)
            else:
                # apply other activation functions normally
                outputs = self.activation(outputs)

        return outputs

# %% [markdown]
# In the case of multi-class classification, in the last layer, we can use the *softmax* transformation as a non-linear transformation. The softmax for the $j$th element of $\mathbf{z}_i$ is $$y_{ij} = \frac{e^{z_{ij}}}{\sum_{k=1}^{K} e^{z_{ik}}}$$ where $K$ is the total number of classes.
#
#
# For example. before softmax $$[1.0, 2.0, 3.0, \mathbf{4.0} ]$$ and after: $$[0.0321, 0.0871, 0.2369, \mathbf{0.6439}]$$ (now the sum is equal to one)
#
# We can also now compare the fundamental truth which could be $$[0,0,0,\mathbf{1}]$$ That is to say that class 4 is the good class and that the network predicted correctly.
# ## 6. Bulding a neural network
#
# https://medium.com/geekculture/how-visualizations-help-make-sense-of-deep-learning-a408ab00688f

# %%
n_input = 10
n_output = 2
num_datapoints = 1
input_tensor = torch.randn(num_datapoints, n_input)
dense = Dense(input_units=n_input , output_units=n_output, activation=torch.sigmoid)


# remember to matrix multiply A and B we need the shapes (a1 x a2) (b1 x b2) to be such that a2=b1
# the result will be (a1 x b2)

print(dense.weights.shape)
print(input_tensor.shape)
print(torch.matmul(input_tensor, dense.weights).shape) # this is XW  e.g. (1, 10)x(10, 2) = (1 x 2)

# notice that increasing the number of data points does not change the shape of W!
# This is important - the parameter shape should not change according to the number of datapoints, only their dimenaionality
# Out:
# torch.Size([10, 2])
# torch.Size([1, 10])
# torch.Size([1, 2])

# %%
# if we want to stack multiple dense operations together
hidden_dim = 10
dense1 =  Dense(input_units=n_input , output_units=hidden_dim, activation=torch.sigmoid)
dense2 =  Dense(input_units=hidden_dim , output_units=n_output, activation=F.softmax)
output = dense2(dense1(input_tensor))

# %%
# integrate everything into an overall model

class MyModel(nn.Module):
    def __init__(self, input_units, hidden_units, output_units):
        super(MyModel, self).__init__()
        # Define a Dense layer
        self.dense1 = Dense(input_units, hidden_units, activation=F.relu)
        # Define another Dense layer
        self.dense2 = Dense(hidden_units, output_units, activation=F.softmax)

    def forward(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        return x

    def predict(self, x):
        # Forward pass and get predictions
        preds = self.dense2(self.dense1(x))
        print(preds)  # to check values before argmax
        return torch.argmax(preds, dim=1)

# Example usage
input_units = 10
hidden_units = 5
output_units = 2
model = MyModel(input_units, hidden_units, output_units)

# Create a sample input tensor
input_tensor = torch.randn(5, input_units)

# Get predictions
predictions = model.predict(input_tensor)
print(predictions)
# Out:
# tensor([[7.7313e-01, 2.2687e-01],
#         [6.7768e-01, 3.2232e-01],
#         [1.9639e-06, 1.0000e+00],
#         [2.1213e-06, 1.0000e+00],
#         [3.9666e-02, 9.6033e-01]], grad_fn=<SoftmaxBackward0>)
# tensor([0, 0, 1, 1, 1])
