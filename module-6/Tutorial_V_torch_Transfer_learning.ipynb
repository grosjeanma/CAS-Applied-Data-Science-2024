# %% [markdown]
# # Tutorial V: Transfer Learning

# %% [markdown]
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# In this session we will use the pretrained Inception model to build own image classifier. We will aslo learn how to save our trained models.

# %% [markdown]
# ## 1. Load necessary libraries

# %%
colab = True # set to True is using google colab

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
import shutil
import tarfile

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.hub import download_url_to_file
from torchvision import transforms, datasets
from torch.utils.tensorboard import SummaryWriter

from sklearn.model_selection import train_test_split
from PIL import Image

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Download libraries

# %%
if colab:
    path = os.path.join(os.path.abspath('.')+'material.tgz')
    url = 'https://github.com/neworldemancer/BMLWS/raw/main/tut_files/tpub0320.tgz'
    # p = tf.keras.utils.get_file(path, url)
    # Download compressed file with torch utils

    download_url_to_file(url=url, dst=path)

    tar = tarfile.open(path, "r:gz")
    tar.extractall()
    tar.close()
# Out:
# 100%|██████████| 77.4M/77.4M [00:05<00:00, 14.9MB/s]

# %% [markdown]
# ## 2. Transfer learning

# %% [markdown]
# We load first an inception model with pretrained weights, without the final classifier:

# %%
print(torch.hub.help('pytorch/vision:v0.7.0', 'inception_v3'))
# Out:
#     Inception v3 model architecture from
#     `Rethinking the Inception Architecture for Computer Vision <http://arxiv.org/abs/1512.00567>`_.
#
#     .. note::
#         **Important**: In contrast to the other models the inception_v3 expects tensors with a size of
#         N x 3 x 299 x 299, so ensure your images are sized accordingly.
#
#     Args:
#         weights (:class:`~torchvision.models.Inception_V3_Weights`, optional): The
#             pretrained weights for the model. See
#             :class:`~torchvision.models.Inception_V3_Weights` below for
#             more details, and possible values. By default, no pre-trained
#             weights are used.
#         progress (bool, optional): If True, displays a progress bar of the
#             download to stderr. Default is True.
#         **kwargs: parameters passed to the ``torchvision.models.Inception3``
#             base class. Please refer to the `source code
#             <https://github.com/pytorch/vision/blob/main/torchvision/models/inception.py>`_
#             for more details about this class.
#
#     .. autoclass:: torchvision.models.Inception_V3_Weights
#         :members:
# Using cache found in /Users/marcel/.cache/torch/hub/pytorch_vision_v0.7.0

# %%
base_model = torch.hub.load('pytorch/vision:v0.7.0', 'inception_v3')
# Out:
# Using cache found in /Users/marcel/.cache/torch/hub/pytorch_vision_v0.7.0

# %%
dir(base_model)
# Out:
# ['AuxLogits',
#  'Conv2d_1a_3x3',
#  'Conv2d_2a_3x3',
#  'Conv2d_2b_3x3',
#  'Conv2d_3b_1x1',
#  'Conv2d_4a_3x3',
#  'Mixed_5b',
#  'Mixed_5c',
#  'Mixed_5d',
#  'Mixed_6a',
#  'Mixed_6b',
#  'Mixed_6c',
#  'Mixed_6d',
#  'Mixed_6e',
#  'Mixed_7a',
#  'Mixed_7b',
#  'Mixed_7c',
#  'T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_backward_pre_hooks',
#  '_buffers',
#  '_call_impl',
#  '_compiled_call_impl',
#  '_forward',
#  '_forward_hooks',
#  '_forward_hooks_always_called',
#  '_forward_hooks_with_kwargs',
#  '_forward_pre_hooks',
#  '_forward_pre_hooks_with_kwargs',
#  '_get_backward_hooks',
#  '_get_backward_pre_hooks',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_state_dict_post_hooks',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_state_dict_pre_hooks',
#  '_transform_input',
#  '_version',
#  '_wrapped_call_impl',
#  'add_module',
#  'apply',
#  'aux_logits',
#  'avgpool',
#  'bfloat16',
#  'buffers',
#  'call_super_init',
#  'children',
#  'compile',
#  'cpu',
#  'cuda',
#  'double',
#  'dropout',
#  'dump_patches',
#  'eager_outputs',
#  'eval',
#  'extra_repr',
#  'fc',
#  'float',
#  'forward',
#  'get_buffer',
#  'get_extra_state',
#  'get_parameter',
#  'get_submodule',
#  'half',
#  'ipu',
#  'load_state_dict',
#  'maxpool1',
#  'maxpool2',
#  'modules',
#  'mtia',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'parameters',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_full_backward_hook',
#  'register_full_backward_pre_hook',
#  'register_load_state_dict_post_hook',
#  'register_load_state_dict_pre_hook',
#  'register_module',
#  'register_parameter',
#  'register_state_dict_post_hook',
#  'register_state_dict_pre_hook',
#  'requires_grad_',
#  'set_extra_state',
#  'set_submodule',
#  'share_memory',
#  'state_dict',
#  'to',
#  'to_empty',
#  'train',
#  'training',
#  'transform_input',
#  'type',
#  'xpu',
#  'zero_grad']

# %%
base_model
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
writer = SummaryWriter('runs/inspect_inception_v3')
xs = torch.zeros(1, 3, 299, 299)
writer.add_graph(base_model, xs)
writer.close()

# %%
#%tensorboard --logdir=runs/inspect_inception_v3

# %% [markdown]
# And build a new model using it:

# %%
def fc_head(in_features, n_classes):
    return nn.Sequential(
        nn.Linear(in_features, 64),
        nn.Sigmoid(),
        nn.Linear(64, n_classes)
    )

# %%
# freeze the parameters of the base model
for param in base_model.parameters():
    param.requires_grad = False

# replace existing fc layer with our 2-layer classication head
in_features = base_model.fc.in_features
n_classes = 2
base_model.fc = fc_head(in_features, n_classes)
model = base_model.to(device)

# %%
# Loss function
criterion = nn.CrossEntropyLoss()
# Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def get_predictions(logits):
    # no need to apply softmax, as softmax is a monotonic function
    # probs = F.softmax(logits, dim=1)
    _, predictions = torch.max(logits, dim=1)
    return predictions

# %%
def calculate_accuracy_batch(predictions, labels):
    n_correct = torch.sum(predictions == labels).item()
    n_total = len(labels)
    return n_correct, n_total

# %% [markdown]
# ## 3. Dataset

# %% [markdown]
# The Inception network is trained on natural images: thigs we see around everyday, like sky, flowers, animals, building, cars.
# It builds an hierarchy of features, to describe what it sees.
# This features can be used to train fast on different classes of objects. E.g. [here](https://www.tensorflow.org/tutorials/image_retraining) are more examples on transfer learning.
#
# Here you will see that these features can be even used to detect thngs very different from natural images. Namely we will try to use it to distinguish German text from Italian. We will use 100 samples, taken from 5 German and 5 Italian books, 10 samples each.

# %%
# load images from the ML3 folder into torch dataset

image_transform = transforms.Compose([
    transforms.Resize((299, 299)),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder('ML3', transform=image_transform)

# %%
text_label = dataset.classes
print(text_label)
# Out:
# ['de', 'it']

# %%
for im, lbl in dataset:
    print(lbl, im.shape, im.min(), im.max(), im.mean(), im.std())

    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(2,2))
    plt.imshow(im_numpy)
    plt.show()
    break
# Out:
# 0 torch.Size([3, 299, 299]) tensor(-2.0837) tensor(2.6400) tensor(1.7154) tensor(1.2477)

# %%
#We will take 80% from each for training and 20 for validation

batch_size=10

dataset_tra, dataset_val = torch.utils.data.random_split(dataset, [0.8, 0.2])

# %% [markdown]
# Is this a good way? Why?

# %%
lbls = np.array([lbl for _, lbl in dataset_tra])
print(f'n_class_0 = {np.sum(lbls == 0)}, n_class_1 = {np.sum(lbls == 1)}')
# Out:
# n_class_0 = 42, n_class_1 = 38

# %% [markdown]
# it's better to have a balanced (strtifed) training and validation sets

# %%
n_samples = len(dataset)
lbls = np.array([lbl for _, lbl in dataset])

# obtain indeces of training and validation samples
idx_tra, idx_val = train_test_split(np.arange(len(dataset)), test_size=0.2, stratify=lbls)

dataset_tra = torch.utils.data.Subset(dataset, idx_tra)
dataset_val = torch.utils.data.Subset(dataset, idx_val)

# %%
lbls = np.array([lbl for _, lbl in dataset_tra])
print(f'Training dataset: n_class_0 = {np.sum(lbls == 0)}, n_class_1 = {np.sum(lbls == 1)}')

lbls = np.array([lbl for _, lbl in dataset_val])
print(f'Validation dataset: n_class_0 = {np.sum(lbls == 0)}, n_class_1 = {np.sum(lbls == 1)}')
# Out:
# Training dataset: n_class_0 = 40, n_class_1 = 40
# Validation dataset: n_class_0 = 10, n_class_1 = 10

# %%
# create data loaders
loader_tra = torch.utils.data.DataLoader(dataset_tra, batch_size=batch_size, shuffle=True)
loader_val = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Lets see a sample:

# %%
ims, lbls = next(iter(loader_tra))  # get a batch from the training dataset
print(ims.shape, ims.min(), ims.max(), ims.mean(), ims.std())
for im, lbl in zip(ims, lbls):
    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(2,2))
    plt.imshow(im_numpy)
    plt.title(text_label[lbl])
    plt.show()
# Out:
# torch.Size([10, 3, 299, 299]) tensor(-2.1179) tensor(2.6400) tensor(1.8066) tensor(1.1214)

# %%
model(ims.to(device))
# Out:
# InceptionOutputs(logits=tensor([[-0.1432,  0.2414],
#         [-0.0999,  0.2614],
#         [-0.1296,  0.3015],
#         [-0.1173,  0.2778],
#         [-0.1632,  0.3155],
#         [-0.2258,  0.2988],
#         [-0.1274,  0.2342],
#         [-0.1293,  0.2502],
#         [-0.2003,  0.2764],
#         [-0.1623,  0.3262]], grad_fn=<AddmmBackward0>), aux_logits=tensor([[-0.0395,  0.0158, -0.0190,  ...,  0.0218,  0.0100,  0.0110],
#         [-0.0273, -0.0055, -0.0242,  ...,  0.0581, -0.0037, -0.0235],
#         [-0.0396, -0.0020, -0.0202,  ...,  0.0192, -0.0080,  0.0196],
#         ...,
#         [-0.0277,  0.0080, -0.0361,  ...,  0.0256,  0.0013, -0.0005],
#         [-0.0353,  0.0424, -0.0143,  ...,  0.0200, -0.0293, -0.0141],
#         [-0.0620,  0.0154, -0.0041,  ...,  0.0472, -0.0013,  0.0137]]))

# %%
res = model(ims.to(device))

# %%
type(res)
# Out:
# torchvision.models.inception.InceptionOutputs

# %%
res
# Out:
# InceptionOutputs(logits=tensor([[-0.1415,  0.2649],
#         [-0.1689,  0.3009],
#         [-0.1347,  0.2870],
#         [-0.1159,  0.2481],
#         [-0.1514,  0.2868],
#         [-0.1893,  0.2682],
#         [-0.1453,  0.2715],
#         [-0.1919,  0.2534],
#         [-0.1333,  0.3729],
#         [-0.1400,  0.2625]], grad_fn=<AddmmBackward0>), aux_logits=tensor([[-0.0395,  0.0158, -0.0190,  ...,  0.0218,  0.0100,  0.0110],
#         [-0.0273, -0.0055, -0.0242,  ...,  0.0581, -0.0037, -0.0235],
#         [-0.0396, -0.0020, -0.0202,  ...,  0.0192, -0.0080,  0.0196],
#         ...,
#         [-0.0277,  0.0080, -0.0361,  ...,  0.0256,  0.0013, -0.0005],
#         [-0.0353,  0.0424, -0.0143,  ...,  0.0200, -0.0293, -0.0141],
#         [-0.0620,  0.0154, -0.0041,  ...,  0.0472, -0.0013,  0.0137]]))

# %%
logits = res.logits
logits.shape
# Out:
# torch.Size([10, 2])

# %% [markdown]
# ## 4. Training

# %% [markdown]
# The training is similar to what we saw previously.
#
# Since Inception model is big, this will take a while, even we use GPUs. On your laptop CPU this would probably take ~15 times longer. And we are not training the whole Inception! We have just small thing on top + a very small dataset!

# %% [markdown]
# We will use callback to save checkpoints on each iteration of training. They contain values of trainable variables.

# %%
def train(model, train_loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    n_correct_running = 0
    n_samples_running = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()  # reset gradients
        logits = model(images).logits
        loss = criterion(logits, labels)


        loss.backward()    # compute gradients
        optimizer.step()   # update parameters with gradients

        n_correct, n_samples = calculate_accuracy_batch(get_predictions(logits), labels)
        n_correct_running += n_correct
        n_samples_running += n_samples
        running_loss += loss.item()

    n = len(train_loader)
    return running_loss / n, n_correct_running / n_samples_running

def validate(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    n_correct_running = 0
    n_samples_running = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            logits = model(images)  # at the inference the model outputs just the logits
            loss = criterion(logits, labels)

            n_correct, n_samples = calculate_accuracy_batch(get_predictions(logits), labels)
            n_correct_running += n_correct
            n_samples_running += n_samples
            running_loss += loss.item()

    n = len(val_loader)
    return running_loss / n, n_correct_running / n_samples_running

# %%
def train_model(model, criterion, optimizer, n_epochs, train_loader, val_loader, save_path):
    os.makedirs(save_path, exist_ok=True)

    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'epoch': []}

    for epoch in range(n_epochs):
        train_loss, train_acc = train(model, train_loader, criterion, optimizer)
        val_loss, val_acc = validate(model, val_loader, criterion)

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        history['epoch'].append(epoch)

        save_dict = {'epoch': epoch,
                     'model_state_dict': model.state_dict(),
                     'optimizer_state_dict': optimizer.state_dict(),
                     'history': history,
                     }
        torch.save(save_dict, os.path.join(save_path, f'model_epoch_{epoch:03d}.pth'))

        print(f'Epoch {epoch+1}/{n_epochs} | '
              f'train_loss: {train_loss:.4f}, train_acc: {train_acc:.4f} | '
              f'val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}')

    return history

# %%
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(10,5))
    axs[0].plot(history['epoch'], history['train_loss'])
    axs[0].plot(history['epoch'], history['val_loss'])
    axs[0].legend(('training loss', 'validation loss'), loc='lower right')

    axs[1].plot(history['epoch'], history['train_acc'])
    axs[1].plot(history['epoch'], history['val_acc'])
    axs[1].legend(('training accuracy', 'validation accuracy'), loc='lower right')
    plt.show()

# %%
save_path = 'TL_1'

n_epochs=70

history = train_model(model, criterion, optimizer, n_epochs, loader_tra, loader_val, save_path)
# Out:
# Epoch 1/70 | train_loss: 0.7663, train_acc: 0.4875 | val_loss: 0.6997, val_acc: 0.5000
# Epoch 2/70 | train_loss: 0.6533, train_acc: 0.6125 | val_loss: 1.2420, val_acc: 0.5000
# Epoch 3/70 | train_loss: 0.6242, train_acc: 0.6000 | val_loss: 0.8025, val_acc: 0.5000
# Epoch 4/70 | train_loss: 0.6149, train_acc: 0.6375 | val_loss: 0.6606, val_acc: 0.6000
# Epoch 5/70 | train_loss: 0.6039, train_acc: 0.6625 | val_loss: 0.6542, val_acc: 0.6500
# Epoch 6/70 | train_loss: 0.6336, train_acc: 0.6000 | val_loss: 0.6305, val_acc: 0.6500
# Epoch 7/70 | train_loss: 0.5971, train_acc: 0.7125 | val_loss: 0.6289, val_acc: 0.6500
# Epoch 8/70 | train_loss: 0.5971, train_acc: 0.6375 | val_loss: 0.6316, val_acc: 0.6500
# Epoch 9/70 | train_loss: 0.5953, train_acc: 0.6750 | val_loss: 0.6561, val_acc: 0.6000
# Epoch 10/70 | train_loss: 0.6185, train_acc: 0.6250 | val_loss: 0.6335, val_acc: 0.6500
# Epoch 11/70 | train_loss: 0.6069, train_acc: 0.6750 | val_loss: 0.6282, val_acc: 0.7000
# Epoch 12/70 | train_loss: 0.5515, train_acc: 0.7875 | val_loss: 0.6361, val_acc: 0.6500
# Epoch 13/70 | train_loss: 0.6364, train_acc: 0.6125 | val_loss: 0.6375, val_acc: 0.6500
# Epoch 14/70 | train_loss: 0.5458, train_acc: 0.7125 | val_loss: 0.6385, val_acc: 0.7000
# Epoch 15/70 | train_loss: 0.5643, train_acc: 0.7250 | val_loss: 0.6386, val_acc: 0.6500
# Epoch 16/70 | train_loss: 0.5210, train_acc: 0.8250 | val_loss: 0.6376, val_acc: 0.6500
# Epoch 17/70 | train_loss: 0.5701, train_acc: 0.6875 | val_loss: 0.6612, val_acc: 0.6500
# Epoch 18/70 | train_loss: 0.6063, train_acc: 0.7000 | val_loss: 0.6435, val_acc: 0.7500
# Epoch 19/70 | train_loss: 0.5531, train_acc: 0.6875 | val_loss: 0.6710, val_acc: 0.6500
# Epoch 20/70 | train_loss: 0.5806, train_acc: 0.6875 | val_loss: 0.6367, val_acc: 0.7000
# Epoch 21/70 | train_loss: 0.5113, train_acc: 0.7625 | val_loss: 0.6607, val_acc: 0.6500
# Epoch 22/70 | train_loss: 0.5545, train_acc: 0.7125 | val_loss: 0.6321, val_acc: 0.6500
# Epoch 23/70 | train_loss: 0.5775, train_acc: 0.6625 | val_loss: 0.6489, val_acc: 0.6500
# Epoch 24/70 | train_loss: 0.5576, train_acc: 0.7250 | val_loss: 0.6325, val_acc: 0.6500
# Epoch 25/70 | train_loss: 0.6707, train_acc: 0.6125 | val_loss: 0.6698, val_acc: 0.6500
# Epoch 26/70 | train_loss: 0.5713, train_acc: 0.7250 | val_loss: 0.6484, val_acc: 0.6000
# Epoch 27/70 | train_loss: 0.5236, train_acc: 0.7125 | val_loss: 0.6401, val_acc: 0.6000
# Epoch 28/70 | train_loss: 0.5356, train_acc: 0.7500 | val_loss: 0.6543, val_acc: 0.6000
# Epoch 29/70 | train_loss: 0.5622, train_acc: 0.7125 | val_loss: 0.6761, val_acc: 0.6000
# Epoch 30/70 | train_loss: 0.5550, train_acc: 0.7000 | val_loss: 0.6346, val_acc: 0.6500
# Epoch 31/70 | train_loss: 0.5829, train_acc: 0.6875 | val_loss: 0.6394, val_acc: 0.6500
# Epoch 32/70 | train_loss: 0.5863, train_acc: 0.6750 | val_loss: 0.6793, val_acc: 0.6500
# Epoch 33/70 | train_loss: 0.6382, train_acc: 0.6375 | val_loss: 0.6309, val_acc: 0.6500
# Epoch 34/70 | train_loss: 0.5886, train_acc: 0.6500 | val_loss: 0.6430, val_acc: 0.6000
# Epoch 35/70 | train_loss: 0.4949, train_acc: 0.7625 | val_loss: 0.6861, val_acc: 0.6500
# Epoch 36/70 | train_loss: 0.5634, train_acc: 0.6875 | val_loss: 0.6531, val_acc: 0.6000
# Epoch 37/70 | train_loss: 0.5045, train_acc: 0.7625 | val_loss: 0.6637, val_acc: 0.6000
# Epoch 38/70 | train_loss: 0.4527, train_acc: 0.8125 | val_loss: 0.6862, val_acc: 0.6000
# Epoch 39/70 | train_loss: 0.5561, train_acc: 0.7000 | val_loss: 0.6608, val_acc: 0.6500
# Epoch 40/70 | train_loss: 0.5650, train_acc: 0.7250 | val_loss: 0.6681, val_acc: 0.6500
# Epoch 41/70 | train_loss: 0.5050, train_acc: 0.6625 | val_loss: 0.6710, val_acc: 0.6000
# Epoch 42/70 | train_loss: 0.4878, train_acc: 0.7500 | val_loss: 0.6441, val_acc: 0.6000
# Epoch 43/70 | train_loss: 0.5034, train_acc: 0.7625 | val_loss: 0.6869, val_acc: 0.6500
# Epoch 44/70 | train_loss: 0.5043, train_acc: 0.7375 | val_loss: 0.6465, val_acc: 0.6000
# Epoch 45/70 | train_loss: 0.5174, train_acc: 0.7875 | val_loss: 0.6358, val_acc: 0.7000
# Epoch 46/70 | train_loss: 0.5449, train_acc: 0.7250 | val_loss: 0.6860, val_acc: 0.6500
# Epoch 47/70 | train_loss: 0.5214, train_acc: 0.7375 | val_loss: 0.6742, val_acc: 0.6000
# Epoch 48/70 | train_loss: 0.5941, train_acc: 0.7000 | val_loss: 0.6666, val_acc: 0.6500
# Epoch 49/70 | train_loss: 0.5400, train_acc: 0.7500 | val_loss: 0.7165, val_acc: 0.6500
# Epoch 50/70 | train_loss: 0.5624, train_acc: 0.7125 | val_loss: 0.6592, val_acc: 0.6500
# Epoch 51/70 | train_loss: 0.5049, train_acc: 0.8125 | val_loss: 0.6641, val_acc: 0.6000
# Epoch 52/70 | train_loss: 0.4630, train_acc: 0.7750 | val_loss: 0.6796, val_acc: 0.7000
# Epoch 53/70 | train_loss: 0.4867, train_acc: 0.8125 | val_loss: 0.6426, val_acc: 0.7000
# Epoch 54/70 | train_loss: 0.4933, train_acc: 0.7875 | val_loss: 0.6834, val_acc: 0.7000
# Epoch 55/70 | train_loss: 0.5153, train_acc: 0.7250 | val_loss: 0.6804, val_acc: 0.7000
# Epoch 56/70 | train_loss: 0.5216, train_acc: 0.7375 | val_loss: 0.6786, val_acc: 0.6500
# Epoch 57/70 | train_loss: 0.4503, train_acc: 0.7875 | val_loss: 0.7339, val_acc: 0.6500
# Epoch 58/70 | train_loss: 0.5332, train_acc: 0.7000 | val_loss: 0.6705, val_acc: 0.6500
# Epoch 59/70 | train_loss: 0.5568, train_acc: 0.6750 | val_loss: 0.6914, val_acc: 0.6500
# Epoch 60/70 | train_loss: 0.5380, train_acc: 0.7875 | val_loss: 0.6625, val_acc: 0.6500
# Epoch 61/70 | train_loss: 0.4809, train_acc: 0.7750 | val_loss: 0.6697, val_acc: 0.7000
# Epoch 62/70 | train_loss: 0.4519, train_acc: 0.7625 | val_loss: 0.6447, val_acc: 0.6000
# Epoch 63/70 | train_loss: 0.4348, train_acc: 0.7875 | val_loss: 0.6904, val_acc: 0.6500
# Epoch 64/70 | train_loss: 0.4432, train_acc: 0.7875 | val_loss: 0.6799, val_acc: 0.6000
# Epoch 65/70 | train_loss: 0.5155, train_acc: 0.7375 | val_loss: 0.6359, val_acc: 0.7000
# Epoch 66/70 | train_loss: 0.4829, train_acc: 0.7500 | val_loss: 0.6577, val_acc: 0.7000
# Epoch 67/70 | train_loss: 0.4096, train_acc: 0.8000 | val_loss: 0.7028, val_acc: 0.6500
# Epoch 68/70 | train_loss: 0.4633, train_acc: 0.7875 | val_loss: 0.6831, val_acc: 0.6500
# Epoch 69/70 | train_loss: 0.4258, train_acc: 0.8000 | val_loss: 0.7610, val_acc: 0.6000
# Epoch 70/70 | train_loss: 0.4116, train_acc: 0.8000 | val_loss: 0.7240, val_acc: 0.6500

# %%
plot_history(history)

# %% [markdown]
# We see that training accuracy hits 100% quickly. Why do you think it happens? Consider that loss keeps decreasing.
# Also on such a small dataset our model overfits.

# %% [markdown]
# ## 5. Load trained variables

# %% [markdown]
# If we have the model already created we can easily load the saved training variables values from a checkpoint:

# %%
test_epochs = [0, 5, 11, 24, 69]
for ep in test_epochs:
    d = torch.load(os.path.join(save_path, f'model_epoch_{ep:03d}.pth'))

    model_state_dict = d['model_state_dict']
    model.load_state_dict(model_state_dict)

    loss, acc = validate(model, loader_val, criterion)
    print(f'Epoch {ep} | val_loss: {loss:.4f}, val_acc: {acc:.4f}')
# Out:
# /var/folders/vt/ylsvf5fn1d7_gznl9zf0z0tr0000gn/T/ipykernel_6811/422421540.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(os.path.join(save_path, f'model_epoch_{ep:03d}.pth'))
# Epoch 0 | val_loss: 0.6997, val_acc: 0.5000
# Epoch 5 | val_loss: 0.6305, val_acc: 0.6500
# Epoch 11 | val_loss: 0.6361, val_acc: 0.6500
# Epoch 24 | val_loss: 0.6698, val_acc: 0.6500
# Epoch 69 | val_loss: 0.7240, val_acc: 0.6500

# %% [markdown]
# ## 6. Saving for inference.

# %% [markdown]
# In pytorch it's easy to save a model for inference:

# %%
# export the model for inference
torch.save(model, 'inference_model.pth')

# %% [markdown]
# ## 7. Inference

# %%
loaded_model = torch.load('inference_model.pth')
loaded_model = loaded_model.to(device)
loaded_model.eval();  # set the model to inference mode
# Out:
# /var/folders/vt/ylsvf5fn1d7_gznl9zf0z0tr0000gn/T/ipykernel_6811/140781185.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load('inference_model.pth')

# %%
# get an image:
im = Image.open('ML3/it/1_1.jpg')
# convert to tensor
im_tensor = image_transform(im)
# add batch dimension
im_tensor = im_tensor.unsqueeze(0).to(device)

print(im_tensor.shape)
# Out:
# torch.Size([1, 3, 299, 299])

# %%
# get the logits and class
with torch.no_grad():
    logits = loaded_model(im_tensor)
    probs = F.softmax(logits, dim=1)
    pred = get_predictions(logits)

probs = probs.cpu().numpy()[0]  # only one element in the batch
pred = pred.cpu().numpy()[0]
print(probs[pred], text_label[pred])
# Out:
# 0.90563506 it

# %% [markdown]
# ## 8. Improving the results

# %% [markdown]
# Often, as in this sample we don't have anough labeled data in hand. We need to use it as efficient as possible.
# One way to do it is to aply training data augmentation: we can slightly distort it, e.g. rescale, to effectively multiply the dataset.

# %% [markdown]
# We will generate rescaled images, minimum - to have smaller dimension equal 256, maximum - 130%. Let's define a function which will do this job:

# %%
# load images from the ML3 folder into torch dataset

image_transform = transforms.Compose([
    transforms.Resize((299, 299)),

    #transforms.RandomCrop(512, pad_if_needed=True, fill=255),
    #transforms.RandomCrop(299),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder('ML3', transform=image_transform)

# %%
for im, lbl in dataset:
    print(lbl, im.shape, im.min(), im.max(), im.mean(), im.std())

    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(2,2))
    plt.imshow(im_numpy)
    plt.show()
    break
# Out:
# 0 torch.Size([3, 299, 299]) tensor(-2.0837) tensor(2.6400) tensor(1.7154) tensor(1.2477)

# %%
n_samples = len(dataset)
lbls = np.array([lbl for _, lbl in dataset])

# obtain indeces of training and validation samples
idx_tra, idx_val = train_test_split(np.arange(len(dataset)), test_size=0.2, stratify=lbls)

dataset_tra = torch.utils.data.Subset(dataset, idx_tra)
dataset_val = torch.utils.data.Subset(dataset, idx_val)

# %%
# create data loaders
loader_tra = torch.utils.data.DataLoader(dataset_tra, batch_size=batch_size, shuffle=True)
loader_val = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# %%
base_model = torch.hub.load('pytorch/vision:v0.7.0', 'inception_v3')

# freeze the parameters of the base model
for param in base_model.parameters():
    param.requires_grad = False

# replace existing fc layer with our 2-layer classication head
in_features = base_model.fc.in_features
n_classes = 2
base_model.fc = fc_head(in_features, n_classes)
model_aug = base_model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss()
# Optimizer
optimizer = optim.Adam(model_aug.parameters(), lr=0.001)
# Out:
# Using cache found in /Users/marcel/.cache/torch/hub/pytorch_vision_v0.7.0
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(

# %%
save_path = 'TL_2'

n_epochs=200

history = train_model(model_aug, criterion, optimizer, n_epochs, loader_tra, loader_val, save_path)
# Out:
# Epoch 1/200 | train_loss: 0.8369, train_acc: 0.5000 | val_loss: 0.9346, val_acc: 0.4762
# Epoch 2/200 | train_loss: 0.6919, train_acc: 0.5750 | val_loss: 0.7764, val_acc: 0.4762
# Epoch 3/200 | train_loss: 0.6600, train_acc: 0.6375 | val_loss: 0.7098, val_acc: 0.4762
# Epoch 4/200 | train_loss: 0.6055, train_acc: 0.6750 | val_loss: 0.7756, val_acc: 0.5714
# Epoch 5/200 | train_loss: 0.6320, train_acc: 0.6000 | val_loss: 0.7283, val_acc: 0.6190
# Epoch 6/200 | train_loss: 0.6690, train_acc: 0.5500 | val_loss: 0.8337, val_acc: 0.6190
# Epoch 7/200 | train_loss: 0.6037, train_acc: 0.6750 | val_loss: 0.7375, val_acc: 0.6190
# Epoch 8/200 | train_loss: 0.5776, train_acc: 0.6500 | val_loss: 0.8424, val_acc: 0.6190
# Epoch 9/200 | train_loss: 0.5535, train_acc: 0.7125 | val_loss: 0.7900, val_acc: 0.5714
# Epoch 10/200 | train_loss: 0.5640, train_acc: 0.6875 | val_loss: 0.8561, val_acc: 0.6190
# Epoch 11/200 | train_loss: 0.5663, train_acc: 0.6625 | val_loss: 0.7888, val_acc: 0.6667
# Epoch 12/200 | train_loss: 0.5609, train_acc: 0.6875 | val_loss: 0.8120, val_acc: 0.6190
# Epoch 13/200 | train_loss: 0.5172, train_acc: 0.7625 | val_loss: 0.8208, val_acc: 0.6190
# Epoch 14/200 | train_loss: 0.5344, train_acc: 0.7500 | val_loss: 0.8176, val_acc: 0.6190
# Epoch 15/200 | train_loss: 0.5734, train_acc: 0.7375 | val_loss: 0.7869, val_acc: 0.6667
# Epoch 16/200 | train_loss: 0.5565, train_acc: 0.6625 | val_loss: 0.9286, val_acc: 0.6190
# Epoch 17/200 | train_loss: 0.5524, train_acc: 0.6875 | val_loss: 0.8256, val_acc: 0.6667
# Epoch 18/200 | train_loss: 0.5436, train_acc: 0.7375 | val_loss: 0.8396, val_acc: 0.6667
# Epoch 19/200 | train_loss: 0.5947, train_acc: 0.6500 | val_loss: 0.8409, val_acc: 0.6667
# Epoch 20/200 | train_loss: 0.5556, train_acc: 0.7000 | val_loss: 0.7858, val_acc: 0.6667
# Epoch 21/200 | train_loss: 0.5999, train_acc: 0.6625 | val_loss: 0.9794, val_acc: 0.6190
# Epoch 22/200 | train_loss: 0.6018, train_acc: 0.6750 | val_loss: 0.8145, val_acc: 0.6190
# Epoch 23/200 | train_loss: 0.5372, train_acc: 0.7250 | val_loss: 0.9878, val_acc: 0.6190
# Epoch 24/200 | train_loss: 0.5211, train_acc: 0.7750 | val_loss: 0.8514, val_acc: 0.6667
# Epoch 25/200 | train_loss: 0.5407, train_acc: 0.7500 | val_loss: 0.8016, val_acc: 0.6667
# Epoch 26/200 | train_loss: 0.4926, train_acc: 0.7500 | val_loss: 1.0289, val_acc: 0.6190
# Epoch 27/200 | train_loss: 0.5370, train_acc: 0.6625 | val_loss: 0.9254, val_acc: 0.6190
# Epoch 28/200 | train_loss: 0.5024, train_acc: 0.7625 | val_loss: 0.8908, val_acc: 0.6667
# Epoch 29/200 | train_loss: 0.4655, train_acc: 0.7750 | val_loss: 0.9476, val_acc: 0.7143
# Epoch 30/200 | train_loss: 0.5005, train_acc: 0.7625 | val_loss: 0.9321, val_acc: 0.6667
# Epoch 31/200 | train_loss: 0.5104, train_acc: 0.7375 | val_loss: 0.9084, val_acc: 0.6667
# Epoch 32/200 | train_loss: 0.5203, train_acc: 0.7000 | val_loss: 0.9636, val_acc: 0.6667
# Epoch 33/200 | train_loss: 0.5632, train_acc: 0.6750 | val_loss: 0.9724, val_acc: 0.6667
# Epoch 34/200 | train_loss: 0.5766, train_acc: 0.7250 | val_loss: 0.8341, val_acc: 0.6190
# Epoch 35/200 | train_loss: 0.5059, train_acc: 0.7875 | val_loss: 1.2440, val_acc: 0.5714
# Epoch 36/200 | train_loss: 0.5775, train_acc: 0.7375 | val_loss: 0.8835, val_acc: 0.6667
# Epoch 37/200 | train_loss: 0.4764, train_acc: 0.7750 | val_loss: 1.0242, val_acc: 0.6667
# Epoch 38/200 | train_loss: 0.5208, train_acc: 0.7500 | val_loss: 0.9613, val_acc: 0.6667
# Epoch 39/200 | train_loss: 0.4794, train_acc: 0.7875 | val_loss: 1.0107, val_acc: 0.7143
# Epoch 40/200 | train_loss: 0.5404, train_acc: 0.7000 | val_loss: 0.9349, val_acc: 0.6667
# Epoch 41/200 | train_loss: 0.5701, train_acc: 0.7250 | val_loss: 0.9362, val_acc: 0.6667
# Epoch 42/200 | train_loss: 0.5517, train_acc: 0.7000 | val_loss: 1.1822, val_acc: 0.6190
# Epoch 43/200 | train_loss: 0.5675, train_acc: 0.6750 | val_loss: 0.8827, val_acc: 0.6667
# Epoch 44/200 | train_loss: 0.4744, train_acc: 0.7875 | val_loss: 1.0247, val_acc: 0.7143
# Epoch 45/200 | train_loss: 0.4436, train_acc: 0.7875 | val_loss: 1.0262, val_acc: 0.6667
# Epoch 46/200 | train_loss: 0.5633, train_acc: 0.7250 | val_loss: 0.8868, val_acc: 0.6667
# Epoch 47/200 | train_loss: 0.5462, train_acc: 0.7125 | val_loss: 1.0160, val_acc: 0.7143
# Epoch 48/200 | train_loss: 0.4619, train_acc: 0.8000 | val_loss: 0.8487, val_acc: 0.6667
# Epoch 49/200 | train_loss: 0.4983, train_acc: 0.7500 | val_loss: 1.0303, val_acc: 0.6667
# Epoch 50/200 | train_loss: 0.4751, train_acc: 0.7500 | val_loss: 0.9281, val_acc: 0.6667
# Epoch 51/200 | train_loss: 0.4169, train_acc: 0.8250 | val_loss: 1.0470, val_acc: 0.6190
# Epoch 52/200 | train_loss: 0.3945, train_acc: 0.8625 | val_loss: 1.1089, val_acc: 0.7143
# Epoch 53/200 | train_loss: 0.4574, train_acc: 0.7875 | val_loss: 1.0298, val_acc: 0.6667
# Epoch 54/200 | train_loss: 0.4553, train_acc: 0.8125 | val_loss: 1.0893, val_acc: 0.7619
# Epoch 55/200 | train_loss: 0.4645, train_acc: 0.8000 | val_loss: 1.0881, val_acc: 0.6667
# Epoch 56/200 | train_loss: 0.4711, train_acc: 0.7375 | val_loss: 1.0344, val_acc: 0.6667
# Epoch 57/200 | train_loss: 0.5075, train_acc: 0.7750 | val_loss: 1.0725, val_acc: 0.7143
# Epoch 58/200 | train_loss: 0.4599, train_acc: 0.7750 | val_loss: 0.9669, val_acc: 0.6667
# Epoch 59/200 | train_loss: 0.4589, train_acc: 0.7625 | val_loss: 0.9606, val_acc: 0.6667
# Epoch 60/200 | train_loss: 0.4167, train_acc: 0.8125 | val_loss: 1.1655, val_acc: 0.7143
# Epoch 61/200 | train_loss: 0.5447, train_acc: 0.7000 | val_loss: 1.0059, val_acc: 0.7143
# Epoch 62/200 | train_loss: 0.4209, train_acc: 0.8500 | val_loss: 1.0461, val_acc: 0.7143
# Epoch 63/200 | train_loss: 0.4729, train_acc: 0.8125 | val_loss: 1.1178, val_acc: 0.7143
# Epoch 64/200 | train_loss: 0.5040, train_acc: 0.7375 | val_loss: 1.1068, val_acc: 0.7143
# Epoch 65/200 | train_loss: 0.4724, train_acc: 0.8000 | val_loss: 1.0626, val_acc: 0.6667
# Epoch 66/200 | train_loss: 0.4553, train_acc: 0.7625 | val_loss: 1.0053, val_acc: 0.6667
# Epoch 67/200 | train_loss: 0.4495, train_acc: 0.7875 | val_loss: 1.1914, val_acc: 0.7619
# Epoch 68/200 | train_loss: 0.4704, train_acc: 0.7625 | val_loss: 0.8781, val_acc: 0.6190
# Epoch 69/200 | train_loss: 0.4264, train_acc: 0.7875 | val_loss: 1.1319, val_acc: 0.7143
# Epoch 70/200 | train_loss: 0.4236, train_acc: 0.8000 | val_loss: 1.1363, val_acc: 0.7143
# Epoch 71/200 | train_loss: 0.4532, train_acc: 0.7750 | val_loss: 1.0316, val_acc: 0.6667
# Epoch 72/200 | train_loss: 0.4419, train_acc: 0.7750 | val_loss: 1.2646, val_acc: 0.6667
# Epoch 73/200 | train_loss: 0.4445, train_acc: 0.8125 | val_loss: 1.1862, val_acc: 0.7143
# Epoch 74/200 | train_loss: 0.4155, train_acc: 0.8250 | val_loss: 0.9182, val_acc: 0.6190
# Epoch 75/200 | train_loss: 0.4611, train_acc: 0.7875 | val_loss: 1.1793, val_acc: 0.7143
# Epoch 76/200 | train_loss: 0.4192, train_acc: 0.8000 | val_loss: 1.1085, val_acc: 0.7143
# Epoch 77/200 | train_loss: 0.4056, train_acc: 0.8375 | val_loss: 1.1441, val_acc: 0.7143
# Epoch 78/200 | train_loss: 0.3924, train_acc: 0.8375 | val_loss: 1.1137, val_acc: 0.7143
# Epoch 79/200 | train_loss: 0.5311, train_acc: 0.7500 | val_loss: 1.0825, val_acc: 0.7143
# Epoch 80/200 | train_loss: 0.5558, train_acc: 0.7375 | val_loss: 1.1667, val_acc: 0.7143
# Epoch 81/200 | train_loss: 0.4210, train_acc: 0.8375 | val_loss: 1.2188, val_acc: 0.7143
# Epoch 82/200 | train_loss: 0.4765, train_acc: 0.7875 | val_loss: 1.0265, val_acc: 0.6190
# Epoch 83/200 | train_loss: 0.4309, train_acc: 0.7500 | val_loss: 1.1575, val_acc: 0.7143
# Epoch 84/200 | train_loss: 0.5241, train_acc: 0.7250 | val_loss: 1.0900, val_acc: 0.7143
# Epoch 85/200 | train_loss: 0.4621, train_acc: 0.7625 | val_loss: 0.9850, val_acc: 0.7143
# Epoch 86/200 | train_loss: 0.4382, train_acc: 0.8250 | val_loss: 0.9760, val_acc: 0.6667
# Epoch 87/200 | train_loss: 0.5397, train_acc: 0.7500 | val_loss: 1.3192, val_acc: 0.7143
# Epoch 88/200 | train_loss: 0.4944, train_acc: 0.7125 | val_loss: 0.8853, val_acc: 0.6190
# Epoch 89/200 | train_loss: 0.4585, train_acc: 0.8000 | val_loss: 1.1436, val_acc: 0.8095
# Epoch 90/200 | train_loss: 0.3947, train_acc: 0.7500 | val_loss: 1.1697, val_acc: 0.7143
# Epoch 91/200 | train_loss: 0.4168, train_acc: 0.8500 | val_loss: 1.0100, val_acc: 0.6667
# Epoch 92/200 | train_loss: 0.4278, train_acc: 0.8250 | val_loss: 1.2652, val_acc: 0.7619
# Epoch 93/200 | train_loss: 0.4453, train_acc: 0.7750 | val_loss: 0.9944, val_acc: 0.6667
# Epoch 94/200 | train_loss: 0.4719, train_acc: 0.7625 | val_loss: 1.1225, val_acc: 0.7143
# Epoch 95/200 | train_loss: 0.4586, train_acc: 0.7625 | val_loss: 1.1398, val_acc: 0.6667
# Epoch 96/200 | train_loss: 0.5423, train_acc: 0.7875 | val_loss: 0.9905, val_acc: 0.5714
# Epoch 97/200 | train_loss: 0.4588, train_acc: 0.7750 | val_loss: 1.1830, val_acc: 0.7143
# Epoch 98/200 | train_loss: 0.4749, train_acc: 0.7500 | val_loss: 0.9858, val_acc: 0.6667
# Epoch 99/200 | train_loss: 0.4061, train_acc: 0.8000 | val_loss: 1.1823, val_acc: 0.7143
# Epoch 100/200 | train_loss: 0.4546, train_acc: 0.8000 | val_loss: 1.0907, val_acc: 0.6667
# Epoch 101/200 | train_loss: 0.4542, train_acc: 0.7625 | val_loss: 1.1193, val_acc: 0.7143
# Epoch 102/200 | train_loss: 0.4889, train_acc: 0.7750 | val_loss: 1.2923, val_acc: 0.7143
# Epoch 103/200 | train_loss: 0.3960, train_acc: 0.8250 | val_loss: 1.0044, val_acc: 0.7143
# Epoch 104/200 | train_loss: 0.4796, train_acc: 0.7500 | val_loss: 1.0334, val_acc: 0.7143
# Epoch 105/200 | train_loss: 0.4791, train_acc: 0.7375 | val_loss: 1.0543, val_acc: 0.7143
# Epoch 106/200 | train_loss: 0.4198, train_acc: 0.7875 | val_loss: 1.0689, val_acc: 0.7143
# Epoch 107/200 | train_loss: 0.4684, train_acc: 0.7875 | val_loss: 1.2109, val_acc: 0.7143
# Epoch 108/200 | train_loss: 0.4101, train_acc: 0.8500 | val_loss: 1.1686, val_acc: 0.7143
# Epoch 109/200 | train_loss: 0.4807, train_acc: 0.7375 | val_loss: 1.1460, val_acc: 0.7143
# Epoch 110/200 | train_loss: 0.4074, train_acc: 0.7625 | val_loss: 1.1245, val_acc: 0.7143
# Epoch 111/200 | train_loss: 0.5006, train_acc: 0.7500 | val_loss: 1.2936, val_acc: 0.7143
# Epoch 112/200 | train_loss: 0.5486, train_acc: 0.7375 | val_loss: 1.0156, val_acc: 0.6667
# Epoch 113/200 | train_loss: 0.4719, train_acc: 0.7875 | val_loss: 1.1403, val_acc: 0.7143
# Epoch 114/200 | train_loss: 0.5147, train_acc: 0.7375 | val_loss: 1.2566, val_acc: 0.7143
# Epoch 115/200 | train_loss: 0.5412, train_acc: 0.7500 | val_loss: 0.9624, val_acc: 0.5714
# Epoch 116/200 | train_loss: 0.4141, train_acc: 0.7875 | val_loss: 1.3101, val_acc: 0.7619
# Epoch 117/200 | train_loss: 0.5164, train_acc: 0.7250 | val_loss: 1.1002, val_acc: 0.6667
# Epoch 118/200 | train_loss: 0.5046, train_acc: 0.7250 | val_loss: 1.0376, val_acc: 0.6667
# Epoch 119/200 | train_loss: 0.4596, train_acc: 0.8250 | val_loss: 1.2990, val_acc: 0.8095
# Epoch 120/200 | train_loss: 0.4272, train_acc: 0.7750 | val_loss: 1.2230, val_acc: 0.7143
# Epoch 121/200 | train_loss: 0.4785, train_acc: 0.7625 | val_loss: 0.9719, val_acc: 0.6667
# Epoch 122/200 | train_loss: 0.3804, train_acc: 0.8250 | val_loss: 1.4031, val_acc: 0.7619
# Epoch 123/200 | train_loss: 0.4630, train_acc: 0.7625 | val_loss: 1.2553, val_acc: 0.7143
# Epoch 124/200 | train_loss: 0.4139, train_acc: 0.8375 | val_loss: 1.2105, val_acc: 0.7143
# Epoch 125/200 | train_loss: 0.3361, train_acc: 0.8500 | val_loss: 1.3075, val_acc: 0.7143
# Epoch 126/200 | train_loss: 0.4154, train_acc: 0.8125 | val_loss: 1.1945, val_acc: 0.6667
# Epoch 127/200 | train_loss: 0.4359, train_acc: 0.7750 | val_loss: 1.2951, val_acc: 0.7143
# Epoch 128/200 | train_loss: 0.5426, train_acc: 0.7625 | val_loss: 1.2262, val_acc: 0.6667
# Epoch 129/200 | train_loss: 0.4131, train_acc: 0.8250 | val_loss: 1.2463, val_acc: 0.7143
# Epoch 130/200 | train_loss: 0.5345, train_acc: 0.7375 | val_loss: 1.3910, val_acc: 0.7143
# Epoch 131/200 | train_loss: 0.3938, train_acc: 0.8250 | val_loss: 1.1359, val_acc: 0.6667
# Epoch 132/200 | train_loss: 0.4239, train_acc: 0.7875 | val_loss: 1.2010, val_acc: 0.7143
# Epoch 133/200 | train_loss: 0.4677, train_acc: 0.7750 | val_loss: 1.0619, val_acc: 0.6667
# Epoch 134/200 | train_loss: 0.3878, train_acc: 0.8500 | val_loss: 1.3174, val_acc: 0.7619
# Epoch 135/200 | train_loss: 0.4481, train_acc: 0.7375 | val_loss: 1.0542, val_acc: 0.7143
# Epoch 136/200 | train_loss: 0.4445, train_acc: 0.7875 | val_loss: 1.1468, val_acc: 0.6667
# Epoch 137/200 | train_loss: 0.5148, train_acc: 0.7250 | val_loss: 0.9949, val_acc: 0.6667
# Epoch 138/200 | train_loss: 0.4053, train_acc: 0.8250 | val_loss: 1.2308, val_acc: 0.7143
# Epoch 139/200 | train_loss: 0.4823, train_acc: 0.7250 | val_loss: 1.0387, val_acc: 0.6667
# Epoch 140/200 | train_loss: 0.3596, train_acc: 0.8625 | val_loss: 1.1202, val_acc: 0.6667
# Epoch 141/200 | train_loss: 0.4238, train_acc: 0.8125 | val_loss: 1.3517, val_acc: 0.7143
# Epoch 142/200 | train_loss: 0.3668, train_acc: 0.8125 | val_loss: 1.4722, val_acc: 0.7143
# Epoch 143/200 | train_loss: 0.3945, train_acc: 0.8250 | val_loss: 1.2612, val_acc: 0.6667
# Epoch 144/200 | train_loss: 0.3689, train_acc: 0.8750 | val_loss: 1.2599, val_acc: 0.6667
# Epoch 145/200 | train_loss: 0.3244, train_acc: 0.8625 | val_loss: 1.2992, val_acc: 0.7143
# Epoch 146/200 | train_loss: 0.4576, train_acc: 0.7500 | val_loss: 1.2999, val_acc: 0.6667
# Epoch 147/200 | train_loss: 0.3973, train_acc: 0.8500 | val_loss: 1.2682, val_acc: 0.6667
# Epoch 148/200 | train_loss: 0.4464, train_acc: 0.8250 | val_loss: 1.3217, val_acc: 0.7143
# Epoch 149/200 | train_loss: 0.4654, train_acc: 0.8125 | val_loss: 1.0688, val_acc: 0.6190
# Epoch 150/200 | train_loss: 0.4249, train_acc: 0.7875 | val_loss: 1.3339, val_acc: 0.7143
# Epoch 151/200 | train_loss: 0.3752, train_acc: 0.8500 | val_loss: 1.2194, val_acc: 0.7143
# Epoch 152/200 | train_loss: 0.4333, train_acc: 0.8125 | val_loss: 1.3652, val_acc: 0.8095
# Epoch 153/200 | train_loss: 0.5079, train_acc: 0.8125 | val_loss: 1.0864, val_acc: 0.6667
# Epoch 154/200 | train_loss: 0.4368, train_acc: 0.7750 | val_loss: 1.0947, val_acc: 0.6667
# Epoch 155/200 | train_loss: 0.3914, train_acc: 0.8250 | val_loss: 1.3033, val_acc: 0.7619
# Epoch 156/200 | train_loss: 0.4267, train_acc: 0.8000 | val_loss: 1.2452, val_acc: 0.7143
# Epoch 157/200 | train_loss: 0.3913, train_acc: 0.8125 | val_loss: 1.3344, val_acc: 0.7143
# Epoch 158/200 | train_loss: 0.5025, train_acc: 0.7625 | val_loss: 1.4650, val_acc: 0.7143
# Epoch 159/200 | train_loss: 0.4542, train_acc: 0.7875 | val_loss: 1.0180, val_acc: 0.7143
# Epoch 160/200 | train_loss: 0.3942, train_acc: 0.8125 | val_loss: 1.3722, val_acc: 0.8095
# Epoch 161/200 | train_loss: 0.3685, train_acc: 0.8250 | val_loss: 1.3931, val_acc: 0.7619
# Epoch 162/200 | train_loss: 0.3659, train_acc: 0.8375 | val_loss: 1.3029, val_acc: 0.6667
# Epoch 163/200 | train_loss: 0.3766, train_acc: 0.8625 | val_loss: 1.4015, val_acc: 0.7143
# Epoch 164/200 | train_loss: 0.4149, train_acc: 0.8625 | val_loss: 1.5044, val_acc: 0.7619
# Epoch 165/200 | train_loss: 0.5530, train_acc: 0.7500 | val_loss: 1.1279, val_acc: 0.6667
# Epoch 166/200 | train_loss: 0.5837, train_acc: 0.7875 | val_loss: 1.4535, val_acc: 0.7143
# Epoch 167/200 | train_loss: 0.4853, train_acc: 0.7500 | val_loss: 1.0782, val_acc: 0.6190
# Epoch 168/200 | train_loss: 0.3891, train_acc: 0.8500 | val_loss: 1.3175, val_acc: 0.7143
# Epoch 169/200 | train_loss: 0.4800, train_acc: 0.8375 | val_loss: 1.4223, val_acc: 0.7619
# Epoch 170/200 | train_loss: 0.4088, train_acc: 0.7625 | val_loss: 1.3475, val_acc: 0.7143
# Epoch 171/200 | train_loss: 0.4576, train_acc: 0.8000 | val_loss: 1.3218, val_acc: 0.7143
# Epoch 172/200 | train_loss: 0.3621, train_acc: 0.8625 | val_loss: 1.5957, val_acc: 0.7619
# Epoch 173/200 | train_loss: 0.3907, train_acc: 0.8125 | val_loss: 1.3756, val_acc: 0.7619
# Epoch 174/200 | train_loss: 0.4484, train_acc: 0.8375 | val_loss: 1.3189, val_acc: 0.7143
# Epoch 175/200 | train_loss: 0.3774, train_acc: 0.8375 | val_loss: 1.3403, val_acc: 0.7143
# Epoch 176/200 | train_loss: 0.4834, train_acc: 0.7875 | val_loss: 1.3856, val_acc: 0.7143
# Epoch 177/200 | train_loss: 0.4641, train_acc: 0.7750 | val_loss: 1.3106, val_acc: 0.7143
# Epoch 178/200 | train_loss: 0.4696, train_acc: 0.7875 | val_loss: 1.1481, val_acc: 0.6667
# Epoch 179/200 | train_loss: 0.3788, train_acc: 0.7750 | val_loss: 1.5122, val_acc: 0.7619
# Epoch 180/200 | train_loss: 0.4019, train_acc: 0.7875 | val_loss: 1.2830, val_acc: 0.6667
# Epoch 181/200 | train_loss: 0.4364, train_acc: 0.8000 | val_loss: 1.3490, val_acc: 0.6667
# Epoch 182/200 | train_loss: 0.4323, train_acc: 0.7875 | val_loss: 1.4233, val_acc: 0.6667
# Epoch 183/200 | train_loss: 0.4857, train_acc: 0.7875 | val_loss: 1.1382, val_acc: 0.6667
# Epoch 184/200 | train_loss: 0.4312, train_acc: 0.8125 | val_loss: 1.2895, val_acc: 0.6667
# Epoch 185/200 | train_loss: 0.3787, train_acc: 0.8500 | val_loss: 1.3867, val_acc: 0.7143
# Epoch 186/200 | train_loss: 0.4373, train_acc: 0.7625 | val_loss: 1.1410, val_acc: 0.6667
# Epoch 187/200 | train_loss: 0.4288, train_acc: 0.8000 | val_loss: 1.4780, val_acc: 0.7143
# Epoch 188/200 | train_loss: 0.3054, train_acc: 0.8750 | val_loss: 1.4308, val_acc: 0.7143
# Epoch 189/200 | train_loss: 0.4688, train_acc: 0.7750 | val_loss: 1.2852, val_acc: 0.6667
# Epoch 190/200 | train_loss: 0.4553, train_acc: 0.7750 | val_loss: 1.3811, val_acc: 0.6667
# Epoch 191/200 | train_loss: 0.4113, train_acc: 0.7875 | val_loss: 1.4209, val_acc: 0.7143
# Epoch 192/200 | train_loss: 0.3698, train_acc: 0.8125 | val_loss: 1.5549, val_acc: 0.7143
# Epoch 193/200 | train_loss: 0.3639, train_acc: 0.8125 | val_loss: 1.3522, val_acc: 0.6667
# Epoch 194/200 | train_loss: 0.3575, train_acc: 0.8000 | val_loss: 1.3964, val_acc: 0.6667
# Epoch 195/200 | train_loss: 0.4029, train_acc: 0.8125 | val_loss: 1.3568, val_acc: 0.6190
# Epoch 196/200 | train_loss: 0.4113, train_acc: 0.8625 | val_loss: 1.4972, val_acc: 0.7143
# Epoch 197/200 | train_loss: 0.4171, train_acc: 0.7750 | val_loss: 1.2838, val_acc: 0.6667
# Epoch 198/200 | train_loss: 0.6393, train_acc: 0.6500 | val_loss: 1.4726, val_acc: 0.7619
# Epoch 199/200 | train_loss: 0.4767, train_acc: 0.8000 | val_loss: 1.2528, val_acc: 0.7143
# Epoch 200/200 | train_loss: 0.4132, train_acc: 0.8125 | val_loss: 1.0319, val_acc: 0.6190

# %%
plot_history(history)

# %% [markdown]
# We had a REEEALLY small dataset for such a complicated task. Does it really generalize? mb it just memorizes all the images we fed into it? Lets perform a test. `w1.PNG` and `w2.PNG` are text screenshots from wikipedia in [Italian](https://it.wikipedia.org/wiki/Apprendimento_automatico) and [German](https://de.wikipedia.org/wiki/Maschinelles_Lernen).

# %% [markdown]
# ## 9. Exersize 1

# %%
# load images
im_wiki_1 = plt.imread('ML3/w1.jpg')
im_wiki_2 = plt.imread('ML3/w2.jpg')

# %% [markdown]
# visualize the samples and perform inference

# %%
...

# %% [markdown]
# ## 10. Excercises

# %% [markdown]
# Do in 4 groups (35 min), in the end present results (2 min/group)

# %% [markdown]
# ### Option 1.

# %% [markdown]
# In the situation when the model is likely to overfit, final performance would especially depend on the training datasets variety.
#
# * Experiment with changes in aspect ratio and scale, using, e.g.
#   `transforms.RandomResizedCrop(299, scale=(0.5, 2.0), ratio=(0.7, 1.3))` instead of the `transforms.RandomCrop`.
# * Which other augmentations would make sense for the text data?
# * Experiment and compare resulting best validation performance and number of epochs until the best validation accuracy.

# %% [markdown]
# ### Option 2.

# %% [markdown]
# In the situation when the model is likely to overfit, final performance would especially depend on the learning rate.
#
# * Plot the best validation accuracy vs learning rate.
# * Plot the number of epochs until the best validation accuracy vs learning rate.
#
# Test learning rates within +/- 1.5 orders of magnitude, i.e. from 30 times smaller to 30 times larger learning rates, than the current one.
#
# Get 3 replicates.

# %% [markdown]
# ### Option 3.

# %% [markdown]
# In the situation when the model is likely to overfit, final performance would especially depend on the model's architecture.
#
# * Plot the best validation accuracy vs width of the first dense layer.
# * Plot the number of epochs until the best validation accuracy vs width.
#
# Test number of features in the first dense layer between 8 and 4096.
#
# Get 3 replicates.

# %% [markdown]
# ### Option 4.

# %% [markdown]
# We tested one model for the backbone of transfer learning. Try other ones (at least 3): https://pytorch.org/vision/stable/models.html.
#
#
# * Plot the best validation accuracy vs model.
# * Plot the number of epochs until the best validation accuracy vs model.
# * Does any model generalize to wiki data?
#
# Run 3 replicates for each model. Input size might vary for different models, adjust the crop size accordingly in parameters to `prepare_training_img`.
